# %%
import pandas as pd
from pathlib import Path
import plotly as plt
from datetime import datetime as dt
from sqlalchemy import create_engine,inspect
from sqlalchemy.ext.declarative import declarative_base
from sqlalchemy import Column, Integer, String, Float 
from sqlalchemy.orm import Session

# %%
master_df = pd.DataFrame()

# %%
def Import_clean_dataset(df,month,year,master_df):
    
    #Format imported dataframe
    df = df.drop(labels=0)
    df = df.reset_index()

    df = df.rename(columns={'Unnamed: 1':'item','Unnamed: 3':'price','Unnamed: 4':'sold', 'Unnamed: 7':'tot_value'})
    df = df[['item','price','sold','tot_value']]
    
    df = df.drop_duplicates()
    df = df.dropna()

    df['item'] = df['item'].str.strip()
    df['sold'] = df['sold'].apply(pd.to_numeric, errors='coerce')
    df['price'] = df['price'].apply(pd.to_numeric, errors='coerce')
    df['tot_value'] = df['tot_value'].str.replace(r',', '')
    df['tot_value'] = df['tot_value'].apply(pd.to_numeric, errors='coerce')
    df['month'] = month
    df['month'] = df['month'].astype(float)
    df['year'] = year
    df['year'] = df['year'].astype(float)
    
    #Create Date Column - conditional statement: formatting month input to follow '00' style
    if month < 10:
        df['date'] = str(20)+str(year)+'-'+ str(0)+str(month)+'-'+'01'
    else:
        df['date'] = str(20)+str(year) + '-'+str(month)+'-'+'01'

    # Append df to master_df    
    master_df = master_df.append(df, ignore_index=True)
    
    return (master_df)

# %% [markdown]
# Set time range

# %%
Starting_year = 17
Ending_year = 22

# %% [markdown]
# Import all Files

# %%
# Loop to through range of the year time period 
for year in range(Starting_year, Ending_year+1):
    main = 'Resources/POSdata/'
    
    # Loop through range of months within a year (12)
    for month in range(1,13):
        
        # Conditional loop to allow for '00' month formatting
        if month >=10:
            file = main + str(year) + "-" + str(month) + '.csv'
        else:
            file = main + str(year) + "-" + str(0) + str(month) + '.csv'
        print(f'The file: {file} has been loaded')
        # Read in csv file to df from the filename created
        df = pd.read_csv(file)

        # Clean dataframe before adding it to master_df
        master_df = Import_clean_dataset(df,month,year,master_df)
# Out:
# The file: Resources/POSdata/17-01.csv has been loaded
# The file: Resources/POSdata/17-02.csv has been loaded
# The file: Resources/POSdata/17-03.csv has been loaded
# The file: Resources/POSdata/17-04.csv has been loaded
# The file: Resources/POSdata/17-05.csv has been loaded
# The file: Resources/POSdata/17-06.csv has been loaded
# The file: Resources/POSdata/17-07.csv has been loaded
# The file: Resources/POSdata/17-08.csv has been loaded
# The file: Resources/POSdata/17-09.csv has been loaded
# The file: Resources/POSdata/17-10.csv has been loaded
# The file: Resources/POSdata/17-11.csv has been loaded
# The file: Resources/POSdata/17-12.csv has been loaded
# The file: Resources/POSdata/18-01.csv has been loaded
# The file: Resources/POSdata/18-02.csv has been loaded
# The file: Resources/POSdata/18-03.csv has been loaded
# The file: Resources/POSdata/18-04.csv has been loaded
# The file: Resources/POSdata/18-05.csv has been loaded
# The file: Resources/POSdata/18-06.csv has been loaded
# The file: Resources/POSdata/18-07.csv has been loaded
# The file: Resources/POSdata/18-08.csv has been loaded
# The file: Resources/POSdata/18-09.csv has been loaded
# The file: Resources/POSdata/18-10.csv has been loaded
# The file: Resources/POSdata/18-11.csv has been loaded
# The file: Resources/POSdata/18-12.csv has been loaded
# The file: Resources/POSdata/19-01.csv has been loaded
# The file: Resources/POSdata/19-02.csv has been loaded
# The file: Resources/POSdata/19-03.csv has been loaded
# The file: Resources/POSdata/19-04.csv has been loaded
# The file: Resources/POSdata/19-05.csv has been loaded
# The file: Resources/POSdata/19-06.csv has been loaded
# The file: Resources/POSdata/19-07.csv has been loaded
# The file: Resources/POSdata/19-08.csv has been loaded
# The file: Resources/POSdata/19-09.csv has been loaded
# The file: Resources/POSdata/19-10.csv has been loaded
# The file: Resources/POSdata/19-11.csv has been loaded
# The file: Resources/POSdata/19-12.csv has been loaded
# The file: Resources/POSdata/20-01.csv has been loaded
# The file: Resources/POSdata/20-02.csv has been loaded
# The file: Resources/POSdata/20-03.csv has been loaded
# The file: Resources/POSdata/20-04.csv has been loaded
# The file: Resources/POSdata/20-05.csv has been loaded
# The file: Resources/POSdata/20-06.csv has been loaded
# The file: Resources/POSdata/20-07.csv has been loaded
# The file: Resources/POSdata/20-08.csv has been loaded
# The file: Resources/POSdata/20-09.csv has been loaded
# The file: Resources/POSdata/20-10.csv has been loaded
# The file: Resources/POSdata/20-11.csv has been loaded
# The file: Resources/POSdata/20-12.csv has been loaded
# The file: Resources/POSdata/21-01.csv has been loaded
# The file: Resources/POSdata/21-02.csv has been loaded
# The file: Resources/POSdata/21-03.csv has been loaded
# The file: Resources/POSdata/21-04.csv has been loaded
# The file: Resources/POSdata/21-05.csv has been loaded
# The file: Resources/POSdata/21-06.csv has been loaded
# The file: Resources/POSdata/21-07.csv has been loaded
# The file: Resources/POSdata/21-08.csv has been loaded
# The file: Resources/POSdata/21-09.csv has been loaded
# The file: Resources/POSdata/21-10.csv has been loaded
# The file: Resources/POSdata/21-11.csv has been loaded
# The file: Resources/POSdata/21-12.csv has been loaded
# The file: Resources/POSdata/22-01.csv has been loaded
# The file: Resources/POSdata/22-02.csv has been loaded
# The file: Resources/POSdata/22-03.csv has been loaded
# The file: Resources/POSdata/22-04.csv has been loaded
# The file: Resources/POSdata/22-05.csv has been loaded
# The file: Resources/POSdata/22-06.csv has been loaded
# The file: Resources/POSdata/22-07.csv has been loaded
# The file: Resources/POSdata/22-08.csv has been loaded
# The file: Resources/POSdata/22-09.csv has been loaded
# The file: Resources/POSdata/22-10.csv has been loaded
# The file: Resources/POSdata/22-11.csv has been loaded
# The file: Resources/POSdata/22-12.csv has been loaded

# %% [markdown]
# Explore master_df

# %%
master_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 8625 entries, 0 to 8624
# Data columns (total 7 columns):
#  #   Column     Non-Null Count  Dtype
# ---  ------     --------------  -----
#  0   item       8625 non-null   object
#  1   price      8625 non-null   float64
#  2   sold       8625 non-null   float64
#  3   tot_value  8625 non-null   float64
#  4   month      8625 non-null   float64
#  5   year       8625 non-null   float64
#  6   date       8625 non-null   object
# dtypes: float64(5), object(2)
# memory usage: 471.8+ KB

# %%
master_df['item'].value_counts().sort_values(ascending=False).head(60)
# Out:
# Plain Naan            73
# Garlic Naan           73
# Palak Paneer          73
# Curry Puffs           72
# White Rice Large      72
# Mustard Chicken       72
# Onion Bhajia          72
# chicken sticks        72
# Samosas - Vege        72
# chicken strips        72
# Butter Chicken        72
# Madras Chicken        72
# Chicken Korma         72
# CH Tikka Masala       72
# Curry Samosas         72
# Beef Vindaloo         72
# Mini Spring Rolls     72
# upgrade ONE SIZE      72
# Chefs SP Chicken.     72
# Large Samosas         72
# Can drinks            72
# Madras Lamb           72
# Lamb Korma            72
# Lamb Vindaloo         72
# Chefs SP Lamb         72
# Chk In Coconut        72
# Rogan Josh            72
# Madras Beef           72
# Vege Korma            72
# Dhal                  72
# Beef Korma            72
# Chefs Sp beef         72
# Mango Chutney         72
# Raita                 72
# K Praw N Coconut      72
# Pappodums x 4         72
# Parathas              72
# Chapattis             72
# Kukulmas Curry        72
# Yellow Rice Large     72
# Vege Butter Chick     72
# Lamb Biryani          72
# Special Fried Rice    72
# Chicken Biryani       72
# Devilled Potato       72
# Pulao                 72
# White Rice Medium     72
# Yellow Rice Medium    72
# Vege St Fry Chick     72
# Chicken Jalfrezi      71
# Channa Masala         71
# Aloo Mattar           71
# Lamb Masala           71
# Potato Bhaji          71
# Paneer Masala         71
# Butter Paneer         71
# upgrade TWO SIZES     71
# Sweet Mango Lassi     71
# Green Bean Garlic     71
# Chicken Vindaloo      71
# Name: item, dtype: int64

# %%
master_df.head()
# Out:
#                 item  price  sold  tot_value  month  year        date
# 0        Curry Puffs    7.0  22.0      147.0    1.0  17.0  2017-01-01
# 1      Large Samosas    6.5  18.0      121.5    1.0  17.0  2017-01-01
# 2     Samosas - Vege    7.5  19.0      142.5    1.0  17.0  2017-01-01
# 3  Mini Spring Rolls    7.5  20.0      150.0    1.0  17.0  2017-01-01
# 4      Curry Samosas    4.0  19.0       85.0    1.0  17.0  2017-01-01

# %%
master_df['item'] = master_df['item'].astype(str)
master_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 8625 entries, 0 to 8624
# Data columns (total 7 columns):
#  #   Column     Non-Null Count  Dtype
# ---  ------     --------------  -----
#  0   item       8625 non-null   object
#  1   price      8625 non-null   float64
#  2   sold       8625 non-null   float64
#  3   tot_value  8625 non-null   float64
#  4   month      8625 non-null   float64
#  5   year       8625 non-null   float64
#  6   date       8625 non-null   object
# dtypes: float64(5), object(2)
# memory usage: 471.8+ KB

# %% [markdown]
# Create and load SQLite dataframe

# %%
Base = declarative_base()

# %% [markdown]
# POS sales data table creation

# %%
class sales(Base):
    __tablename__ = 'sales'
    id = Column(Integer, primary_key=True)
    item = Column(String(255))
    price = Column(Integer)
    sold = Column(Integer)
    tot_value = Column(Float)
    month = Column(Integer)
    year = Column(Integer)
    date = Column(String(255))

# %% [markdown]
# Create engine with SQLite database file location

# %%
engine = create_engine("sqlite:///RestaurantDB.sqlite")

# %%
conn = engine.connect()

# %%
Base.metadata.create_all(engine)

# %%
session = Session(bind=engine)

# %% [markdown]
# Load and commit each row of the master_df into an sql table row

# %%
for row in range(len(master_df)):
    
    sqldata = sales(item = master_df.loc[row,'item'],price = master_df.loc[row,'price'], sold = master_df.loc[row,'sold'],
    tot_value=master_df.loc[row,'tot_value'], month = master_df.loc[row,'month'], year = master_df.loc[row,'year'], date = master_df.loc[row,'date'] )
    session.add(sqldata)

# %%
session.commit()

# %% [markdown]
# Check table for data entry

# %%
inspector = inspect(engine)

# %%
inspector.get_table_names()
# Out:
# ['sales']

# %%
engine.execute('SELECT * FROM sales').fetchall()
# Out:
# [(1, 'Curry Puffs', 7, 22, 147.0, 1, 17, '2017-01-01'),
#  (2, 'Large Samosas', 6.5, 18, 121.5, 1, 17, '2017-01-01'),
#  (3, 'Samosas - Vege', 7.5, 19, 142.5, 1, 17, '2017-01-01'),
#  (4, 'Mini Spring Rolls', 7.5, 20, 150.0, 1, 17, '2017-01-01'),
#  (5, 'Curry Samosas', 4, 19, 85.0, 1, 17, '2017-01-01'),
#  (6, 'Onion Bhajia', 5.5, 55, 325.5, 1, 17, '2017-01-01'),
#  (7, 'chicken sticks', 9, 17, 142.5, 1, 17, '2017-01-01'),
#  (8, 'Tikka Chicken', 9, 5, 42.0, 1, 17, '2017-01-01'),
#  (9, 'chicken strips', 9, 15, 130.0, 1, 17, '2017-01-01'),
#  (10, 'Butter Chicken', 16.5, 236, 4007.0, 1, 17, '2017-01-01'),
#  (11, 'Madras Chicken', 16, 9, 150.0, 1, 17, '2017-01-01'),
#  (12, 'Chicken Korma', 16.5, 34, 583.5, 1, 17, '2017-01-01'),
#  (13, 'CH Tikka Masala', 16, 32, 534.0, 1, 17, '2017-01-01'),
#  (14, 'Chicken Vindaloo', 18, 6, 100.0, 1, 17, '2017-01-01'),
#  (15, 'Mustard Chicken', 18, 25, 422.0, 1, 17, '2017-01-01'),
#  (16, 'Chk In Coconut', 16, 3, 50.0, 1, 17, '2017-01-01'),
#  (17, 'Chicken Jalfrezi', 16, 8, 134.0, 1, 17, '2017-01-01'),
#  (18, 'Chefs SP Chicken.', 18, 14, 234.0, 1, 17, '2017-01-01'),
#  (19, 'Kukulmas Curry', 18, 7, 120.0, 1, 17, '2017-01-01'),
#  (20, 'Rogan Josh', 17, 34, 590.0, 1, 17, '2017-01-01'),
#  (21, 'Palak Gosht', 17, 11, 174.0, 1, 17, '2017-01-01'),
#  (22, 'Madras Lamb', 17, 5, 89.0, 1, 17, '2017-01-01'),
#  (23, 'Lamb Korma', 17, 34, 608.0, 1, 17, '2017-01-01'),
#  (24, 'Lamb Vindaloo', 17, 13, 229.0, 1, 17, '2017-01-01'),
#  (25, 'Chefs SP Lamb', 17, 28, 494.0, 1, 17, '2017-01-01'),
#  (26, 'Lamb Masala', 19, 18, 318.0, 1, 17, '2017-01-01'),
#  (27, 'Beef Vindaloo', 16, 13, 218.0, 1, 17, '2017-01-01'),
#  (28, 'Beef Jalfrezi', 18, 11, 188.0, 1, 17, '2017-01-01'),
#  (29, 'Madras Beef', 16, 22, 368.0, 1, 17, '2017-01-01'),
#  (30, 'Moghlai beef', 18, 16, 274.0, 1, 17, '2017-01-01'),
#  (31, 'Beef Korma', 16, 12, 200.0, 1, 17, '2017-01-01'),
#  (32, 'Chefs Sp beef', 18, 16, 274.0, 1, 17, '2017-01-01'),
#  (33, 'Chefs SP Prawn.', 20, 5, 96.0, 1, 17, '2017-01-01'),
#  (34, 'Mixed Seafood', 21, 4, 80.0, 1, 17, '2017-01-01'),
#  (35, 'K Praw N Coconut', 20, 15, 284.0, 1, 17, '2017-01-01'),
#  (36, 'Spicy King Prawn', 20, 4, 80.0, 1, 17, '2017-01-01'),
#  (37, 'Prawn Vindaloo', 20, 2, 38.0, 1, 17, '2017-01-01'),
#  (38, 'Madras Prawn', 18, 4, 76.0, 1, 17, '2017-01-01'),
#  (39, 'Fish in Coconut', 19, 2, 36.0, 1, 17, '2017-01-01'),
#  (40, 'Chefs SP fish', 18, 11, 214.0, 1, 17, '2017-01-01'),
#  (41, 'Vege Korma', 15, 20, 284.0, 1, 17, '2017-01-01'),
#  (42, 'Potato Bhaji', 14, 4, 57.0, 1, 17, '2017-01-01'),
#  (43, 'Aloo Mattar', 14, 2, 29.0, 1, 17, '2017-01-01'),
#  (44, 'Channa Masala', 14, 4, 56.0, 1, 17, '2017-01-01'),
#  (45, 'Devilled Potato', 14, 9, 126.0, 1, 17, '2017-01-01'),
#  (46, 'Paneer Masala', 15, 2, 30.0, 1, 17, '2017-01-01'),
#  (47, 'Palak Paneer', 15, 17, 263.0, 1, 17, '2017-01-01'),
#  (48, 'Butter Paneer', 15, 7, 107.0, 1, 17, '2017-01-01'),
#  (49, 'Cabbage/Potato', 15, 15, 218.0, 1, 17, '2017-01-01'),
#  (50, 'Devilled Cabbage', 14, 1, 14.0, 1, 17, '2017-01-01'),
#  (51, 'Pumpkin', 15, 5, 77.0, 1, 17, '2017-01-01'),
#  (52, 'Dhal', 14, 16, 228.0, 1, 17, '2017-01-01'),
#  (53, 'Parippu', 0, 6, 72.0, 1, 17, '2017-01-01'),
#  (54, 'Dhal Makhani', 15, 2, 30.0, 1, 17, '2017-01-01'),
#  (55, 'Green Bean Garlic', 14, 9, 129.0, 1, 17, '2017-01-01'),
#  (56, 'Potato Masala', 14, 5, 70.0, 1, 17, '2017-01-01'),
#  (57, 'Potato Curry', 14, 12, 169.0, 1, 17, '2017-01-01'),
#  (58, 'Vege Butter Chick', 15, 16, 240.0, 1, 17, '2017-01-01'),
#  (59, 'Veg Chick Vinloo', 15, 3, 45.0, 1, 17, '2017-01-01'),
#  (60, 'Vege St Fry Chick', 15, 6, 90.0, 1, 17, '2017-01-01'),
#  (61, 'Pepper Chicken', 16, 2, 34.0, 1, 17, '2017-01-01'),
#  (62, 'Pepper Beef', 18, 3, 52.0, 1, 17, '2017-01-01'),
#  (63, 'Pepper K Prawn', 20, 1, 20.0, 1, 17, '2017-01-01'),
#  (64, 'Yellow Rice Medium', 3.5, 39, 152.5, 1, 17, '2017-01-01'),
#  (65, 'White Rice Medium', 3, 21, 77.0, 1, 17, '2017-01-01'),
#  (66, 'Pulao', 7, 14, 102.5, 1, 17, '2017-01-01'),
#  (67, 'Chicken Biryani', 15.5, 17, 244.0, 1, 17, '2017-01-01'),
#  (68, 'Lamb Biryani', 15.5, 12, 178.5, 1, 17, '2017-01-01'),
#  (69, 'Beef Biryani', 15.5, 8, 116.5, 1, 17, '2017-01-01'),
#  (70, 'Special Fried Rice', 14, 10, 143.0, 1, 17, '2017-01-01'),
#  (71, 'Plain Naan', 4, 167, 608.5, 1, 17, '2017-01-01'),
#  (72, 'Garlic Naan', 4, 263, 1099.25, 1, 17, '2017-01-01'),
#  (73, 'Chapattis', 1.5, 37, 63.5, 1, 17, '2017-01-01'),
#  (74, 'Parathas', 2, 54, 118.5, 1, 17, '2017-01-01'),
#  (75, 'Pappodums x 4', 2.75, 72, 200.25, 1, 17, '2017-01-01'),
#  (76, 'Raita', 2.5, 58, 145.0, 1, 17, '2017-01-01'),
#  (77, 'Achar', 3, 2, 6.0, 1, 17, '2017-01-01'),
#  (78, 'Mango Chutney', 2.5, 9, 22.5, 1, 17, '2017-01-01'),
#  (79, 'Laccha', 8, 4, 31.0, 1, 17, '2017-01-01'),
#  (80, 'Almond Kulfi', 3.5, 5, 16.5, 1, 17, '2017-01-01'),
#  (81, 'Mango Kulfi', 3.5, 3, 9.5, 1, 17, '2017-01-01'),
#  (82, 'Ice Cream', 5, 1, 5.0, 1, 17, '2017-01-01'),
#  (83, 'Plain/Salted Lassi', 4, 3, 12.0, 1, 17, '2017-01-01'),
#  (84, 'Sweet Mango Lassi', 4.5, 13, 57.0, 1, 17, '2017-01-01'),
#  (85, 'Mango Nectar', 7, 1, 7.0, 1, 17, '2017-01-01'),
#  (86, 'Yellow Rice Large', 5.5, 118, 577.0, 1, 17, '2017-01-01'),
#  (87, 'White Rice Large', 4, 75, 327.0, 1, 17, '2017-01-01'),
#  (88, 'Devilled Chicken', 18, 2, 34.0, 1, 17, '2017-01-01'),
#  (89, 'Devilled Beff', 16, 2, 34.0, 1, 17, '2017-01-01'),
#  (90, 'Chilli Squid', 20, 2, 40.0, 1, 17, '2017-01-01'),
#  (91, 'Can drinks', 2.5, 32, 80.0, 1, 17, '2017-01-01'),
#  (92, 'Glass Bottle 300ml', 3.5, 8, 28.0, 1, 17, '2017-01-01'),
#  (93, 'Bottled Water', 2, 1, 2.0, 1, 17, '2017-01-01'),
#  (94, 'BYO', 1.5, 28, 42.0, 1, 17, '2017-01-01'),
#  (95, 'upgrade ONE SIZE', 1.5, 31, 45.5, 1, 17, '2017-01-01'),
#  (96, 'upgrade TWO SIZES', 2.75, 6, 16.5, 1, 17, '2017-01-01'),
#  (97, 'Cut Chilli', 1.5, 3, 4.5, 1, 17, '2017-01-01'),
#  (98, 'Devilled Lamb', 19, 4, 70.0, 1, 17, '2017-01-01'),
#  (99, 'Devilled K Prawn', 20, 1, 20.0, 1, 17, '2017-01-01'),
#  (100, '1000 Spic SFY Chicken', 16, 5, 80.0, 1, 17, '2017-01-01'),
#  (101, '1000 Spic SRY Beef', 16, 1, 16.0, 1, 17, '2017-01-01'),
#  (102, '1000 Spic Lamb', 17, 1, 17.0, 1, 17, '2017-01-01'),
#  (103, '1000 Spic K Prawns', 20, 3, 60.0, 1, 17, '2017-01-01'),
#  (104, 'BYO Per Head', 6, 48, 76.5, 1, 17, '2017-01-01'),
#  (105, 'Buchet of Ice', 1.5, 2, 3.0, 1, 17, '2017-01-01'),
#  (106, 'Curry Puffs', 6.5, 19, 127.0, 2, 17, '2017-02-01'),
#  (107, 'Large Samosas', 6.5, 19, 127.5, 2, 17, '2017-02-01'),
#  (108, 'Samosas - Vege', 7.5, 14, 105.0, 2, 17, '2017-02-01'),
#  (109, 'Mini Spring Rolls', 7.5, 17, 127.5, 2, 17, '2017-02-01'),
#  (110, 'Curry Samosas', 4, 16, 73.0, 2, 17, '2017-02-01'),
#  (111, 'Onion Bhajia', 6.5, 61, 362.5, 2, 17, '2017-02-01'),
#  (112, 'chicken sticks', 7.5, 16, 126.0, 2, 17, '2017-02-01'),
#  (113, 'Tikka Chicken', 9, 6, 51.0, 2, 17, '2017-02-01'),
#  (114, 'chicken strips', 9, 15, 127.0, 2, 17, '2017-02-01'),
#  (115, 'Butter Chicken', 16.5, 207, 3477.5, 2, 17, '2017-02-01'),
#  (116, 'Madras Chicken', 16, 11, 178.0, 2, 17, '2017-02-01'),
#  (117, 'Chicken Korma', 16.5, 37, 636.0, 2, 17, '2017-02-01'),
#  (118, 'CH Tikka Masala', 18, 28, 470.0, 2, 17, '2017-02-01'),
#  (119, 'Chicken Vindaloo', 16, 8, 132.0, 2, 17, '2017-02-01'),
#  (120, 'Mustard Chicken', 18, 17, 292.0, 2, 17, '2017-02-01'),
#  (121, 'Chk In Coconut', 18, 5, 86.0, 2, 17, '2017-02-01'),
#  (122, 'Chicken Jalfrezi', 16, 9, 154.0, 2, 17, '2017-02-01'),
#  (123, 'Chefs SP Chicken.', 16, 6, 104.0, 2, 17, '2017-02-01'),
#  (124, 'Kukulmas Curry', 16, 12, 204.0, 2, 17, '2017-02-01'),
#  (125, 'Rogan Josh', 17, 29, 505.0, 2, 17, '2017-02-01'),
#  (126, 'Palak Gosht', 17, 14, 245.0, 2, 17, '2017-02-01'),
#  (127, 'Madras Lamb', 17, 4, 70.0, 2, 17, '2017-02-01'),
#  (128, 'Lamb Korma', 17, 29, 509.0, 2, 17, '2017-02-01'),
#  (129, 'Lamb Vindaloo', 19, 8, 144.0, 2, 17, '2017-02-01'),
#  (130, 'Chefs SP Lamb', 17, 14, 258.0, 2, 17, '2017-02-01'),
#  (131, 'Lamb Masala', 19, 16, 292.0, 2, 17, '2017-02-01'),
#  (132, 'Beef Vindaloo', 16, 17, 282.0, 2, 17, '2017-02-01'),
#  (133, 'Beef Jalfrezi', 16, 14, 224.0, 2, 17, '2017-02-01'),
#  (134, 'Madras Beef', 16, 13, 218.0, 2, 17, '2017-02-01'),
#  (135, 'Moghlai beef', 16, 11, 188.0, 2, 17, '2017-02-01'),
#  (136, 'Beef Korma', 16, 13, 214.0, 2, 17, '2017-02-01'),
#  (137, 'Chefs Sp beef', 16, 13, 218.0, 2, 17, '2017-02-01'),
#  (138, 'Chefs SP Prawn.', 18, 8, 156.0, 2, 17, '2017-02-01'),
#  (139, 'Mixed Seafood', 21, 9, 179.0, 2, 17, '2017-02-01'),
#  (140, 'K Praw N Coconut', 18, 2, 36.0, 2, 17, '2017-02-01'),
#  (141, 'Spicy King Prawn', 18, 5, 94.0, 2, 17, '2017-02-01'),
#  (142, 'Prawn Vindaloo', 20, 3, 58.0, 2, 17, '2017-02-01'),
#  (143, 'Madras Prawn', 18, 2, 38.0, 2, 17, '2017-02-01'),
#  (144, 'Fish in Coconut', 19, 1, 19.0, 2, 17, '2017-02-01'),
#  (145, 'Chefs SP fish', 20, 8, 154.0, 2, 17, '2017-02-01'),
#  (146, 'Vege Korma', 14, 12, 174.0, 2, 17, '2017-02-01'),
#  (147, 'Potato Bhaji', 14, 2, 28.0, 2, 17, '2017-02-01'),
#  (148, 'Aloo Mattar', 15, 8, 114.0, 2, 17, '2017-02-01'),
#  (149, 'Channa Masala', 14, 3, 43.0, 2, 17, '2017-02-01'),
#  (150, 'Devilled Potato', 14, 9, 126.0, 2, 17, '2017-02-01'),
#  (151, 'Paneer Masala', 15, 4, 60.0, 2, 17, '2017-02-01'),
#  (152, 'Palak Paneer', 15, 7, 107.5, 2, 17, '2017-02-01'),
#  (153, 'Butter Paneer', 15, 5, 77.0, 2, 17, '2017-02-01'),
#  (154, 'Cabbage/Potato', 14, 18, 258.0, 2, 17, '2017-02-01'),
#  (155, 'Devilled Cabbage', 14, 5, 71.0, 2, 17, '2017-02-01'),
#  (156, 'Pumpkin', 15, 5, 76.0, 2, 17, '2017-02-01'),
#  (157, 'Dhal', 14, 12, 170.0, 2, 17, '2017-02-01'),
#  (158, 'Parippu', 14, 7, 100.0, 2, 17, '2017-02-01'),
#  (159, 'Dhal Makhani', 15, 2, 30.0, 2, 17, '2017-02-01'),
#  (160, 'Green Bean Garlic', 15, 7, 100.0, 2, 17, '2017-02-01'),
#  (161, 'Potato Masala', 14, 5, 71.0, 2, 17, '2017-02-01'),
#  (162, 'Potato Curry', 14, 4, 56.0, 2, 17, '2017-02-01'),
#  (163, 'Vege Butter Chick', 15, 10, 151.0, 2, 17, '2017-02-01'),
#  (164, 'Veg Chick Vinloo', 15, 4, 60.0, 2, 17, '2017-02-01'),
#  (165, 'Vege St Fry Chick', 15, 4, 60.0, 2, 17, '2017-02-01'),
#  (166, 'Pepper Beef', 16, 2, 34.0, 2, 17, '2017-02-01'),
#  (167, 'Pepper Lamb', 19, 1, 19.0, 2, 17, '2017-02-01'),
#  (168, 'Pepper K Prawn', 20, 2, 40.0, 2, 17, '2017-02-01'),
#  (169, 'Yellow Rice Medium', 3.5, 44, 173.0, 2, 17, '2017-02-01'),
#  (170, 'White Rice Medium', 4, 16, 60.0, 2, 17, '2017-02-01'),
#  (171, 'Pulao', 7, 13, 100.0, 2, 17, '2017-02-01'),
#  (172, 'Chicken Biryani', 15.5, 18, 261.0, 2, 17, '2017-02-01'),
#  (173, 'Lamb Biryani', 14, 12, 175.5, 2, 17, '2017-02-01'),
#  (174, 'Beef Biryani', 14, 6, 87.0, 2, 17, '2017-02-01'),
#  (175, 'Special Fried Rice', 15.5, 18, 256.5, 2, 17, '2017-02-01'),
#  (176, 'Plain Naan', 3.5, 129, 485.0, 2, 17, '2017-02-01'),
#  (177, 'Garlic Naan', 4, 223, 952.0, 2, 17, '2017-02-01'),
#  (178, 'Chapattis', 1.75, 36, 60.5, 2, 17, '2017-02-01'),
#  (179, 'Parathas', 2.5, 52, 113.0, 2, 17, '2017-02-01'),
#  (180, 'Pappodums x 4', 2.75, 70, 193.0, 2, 17, '2017-02-01'),
#  (181, 'Raita', 5.5, 48, 123.0, 2, 17, '2017-02-01'),
#  (182, 'Achar', 3, 1, 3.0, 2, 17, '2017-02-01'),
#  (183, 'Mango Chutney', 2.5, 9, 22.5, 2, 17, '2017-02-01'),
#  (184, 'Laccha', 7, 5, 33.0, 2, 17, '2017-02-01'),
#  (185, 'Almond Kulfi', 3.5, 4, 13.5, 2, 17, '2017-02-01'),
#  (186, 'Mango Kulfi', 3.5, 3, 10.0, 2, 17, '2017-02-01'),
#  (187, 'Curd n Honey', 7, 1, 7.0, 2, 17, '2017-02-01'),
#  (188, 'Ice Cream', 5, 3, 15.0, 2, 17, '2017-02-01'),
#  (189, 'Plain/Salted Lassi', 4, 2, 7.5, 2, 17, '2017-02-01'),
#  (190, 'Sweet Mango Lassi', 4.5, 14, 63.0, 2, 17, '2017-02-01'),
#  (191, 'Mango Nectar', 7, 1, 7.0, 2, 17, '2017-02-01'),
#  (192, 'Falooda', 7, 2, 14.0, 2, 17, '2017-02-01'),
#  (193, 'Chili Naan', 4.75, 1, 4.75, 2, 17, '2017-02-01'),
#  (194, 'Yellow Rice Large', 4.5, 93, 448.5, 2, 17, '2017-02-01'),
#  (195, 'White Rice Large', 5, 64, 276.0, 2, 17, '2017-02-01'),
#  (196, 'Devilled Chicken', 16, 3, 48.0, 2, 17, '2017-02-01'),
#  (197, 'Chilli Squid', 20, 1, 20.0, 2, 17, '2017-02-01'),
#  (198, 'Can drinks', 2.5, 18, 45.0, 2, 17, '2017-02-01'),
#  (199, 'Glass Bottle 300ml', 3.5, 6, 21.0, 2, 17, '2017-02-01'),
#  (200, '1.25L drink', 4.25, 1, 4.25, 2, 17, '2017-02-01'),
#  (201, 'Vege Chk MASALA', 15, 1, 15.0, 2, 17, '2017-02-01'),
#  (202, 'Vege Chk JALFREZI', 15, 3, 45.0, 2, 17, '2017-02-01'),
#  (203, 'Bottled Water', 2, 1, 2.0, 2, 17, '2017-02-01'),
#  (204, 'BYO', 1.5, 4, 6.0, 2, 17, '2017-02-01'),
#  (205, 'upgrade ONE SIZE', 1.5, 18, 27.0, 2, 17, '2017-02-01'),
#  (206, 'upgrade TWO SIZES', 2.75, 11, 30.25, 2, 17, '2017-02-01'),
#  (207, 'TEA Per Person', 3, 1, 3.0, 2, 17, '2017-02-01'),
#  (208, 'Cup Of Coffee', 4.5, 1, 4.5, 2, 17, '2017-02-01'),
#  (209, 'Devilled K Prawn', 20, 1, 20.0, 2, 17, '2017-02-01'),
#  (210, '1000 Spic SFY Chicken', 18, 3, 50.0, 2, 17, '2017-02-01'),
#  (211, '1000 Spic SRY Beef', 16, 1, 16.0, 2, 17, '2017-02-01'),
#  (212, '1000 Spic Lamb', 17, 1, 17.0, 2, 17, '2017-02-01'),
#  (213, 'BYO Per Head', 1.5, 49, 98.63, 2, 17, '2017-02-01'),
#  (214, 'Buchet of Ice', 1.5, 3, 4.5, 2, 17, '2017-02-01'),
#  (215, 'Curry Puffs', 6.5, 28, 188.5, 3, 17, '2017-03-01'),
#  (216, 'Large Samosas', 6.5, 23, 155.5, 3, 17, '2017-03-01'),
#  (217, 'Samosas - Vege', 7.5, 24, 180.0, 3, 17, '2017-03-01'),
#  (218, 'Mini Spring Rolls', 7.5, 14, 100.0, 3, 17, '2017-03-01'),
#  (219, 'Curry Samosas', 4, 18, 82.0, 3, 17, '2017-03-01'),
#  (220, 'Onion Bhajia', 5.5, 52, 309.0, 3, 17, '2017-03-01'),
#  (221, 'chicken sticks', 9, 21, 177.0, 3, 17, '2017-03-01'),
#  (222, 'chicken strips', 8, 15, 128.0, 3, 17, '2017-03-01'),
#  (223, 'Butter Chicken', 16.5, 256, 4339.5, 3, 17, '2017-03-01'),
#  (224, 'Madras Chicken', 16, 8, 134.0, 3, 17, '2017-03-01'),
#  (225, 'Chicken Korma', 18, 34, 573.0, 3, 17, '2017-03-01'),
#  (226, 'CH Tikka Masala', 18, 31, 514.0, 3, 17, '2017-03-01'),
#  (227, 'Chicken Vindaloo', 18, 5, 84.0, 3, 17, '2017-03-01'),
#  (228, 'Mustard Chicken', 18, 23, 390.0, 3, 17, '2017-03-01'),
#  (229, 'Chk In Coconut', 16, 3, 50.0, 3, 17, '2017-03-01'),
#  (230, 'Chicken Jalfrezi', 16, 7, 116.0, 3, 17, '2017-03-01'),
#  (231, 'Chefs SP Chicken.', 18, 12, 200.0, 3, 17, '2017-03-01'),
#  (232, 'Kukulmas Curry', 18, 11, 188.0, 3, 17, '2017-03-01'),
#  (233, 'Rogan Josh', 17, 44, 784.0, 3, 17, '2017-03-01'),
#  (234, 'Palak Gosht', 19, 9, 163.5, 3, 17, '2017-03-01'),
#  (235, 'Madras Lamb', 19, 12, 208.0, 3, 17, '2017-03-01'),
#  (236, 'Lamb Korma', 19, 35, 619.0, 3, 17, '2017-03-01'),
#  (237, 'Lamb Vindaloo', 17, 11, 195.0, 3, 17, '2017-03-01'),
#  (238, 'Chefs SP Lamb', 19, 11, 199.0, 3, 17, '2017-03-01'),
#  (239, 'Lamb Masala', 17, 16, 292.0, 3, 17, '2017-03-01'),
#  (240, 'Beef Vindaloo', 16, 27, 438.0, 3, 17, '2017-03-01'),
#  (241, 'Beef Jalfrezi', 16, 7, 116.0, 3, 17, '2017-03-01'),
#  (242, 'Madras Beef', 18, 25, 418.0, 3, 17, '2017-03-01'),
#  (243, 'Moghlai beef', 16, 10, 168.0, 3, 17, '2017-03-01'),
#  (244, 'Beef Korma', 16, 18, 302.0, 3, 17, '2017-03-01'),
#  (245, 'Chefs Sp beef', 16, 18, 300.0, 3, 17, '2017-03-01'),
#  (246, 'Chefs SP Prawn.', 20, 5, 96.0, 3, 17, '2017-03-01'),
#  (247, 'Mixed Seafood', 21, 7, 143.0, 3, 17, '2017-03-01'),
#  (248, 'K Praw N Coconut', 18, 8, 152.0, 3, 17, '2017-03-01'),
#  (249, 'Spicy King Prawn', 20, 4, 80.0, 3, 17, '2017-03-01'),
#  (250, 'Prawn Vindaloo', 18, 1, 18.0, 3, 17, '2017-03-01'),
#  (251, 'Madras Prawn', 18, 2, 38.0, 3, 17, '2017-03-01'),
#  (252, 'Fish in Coconut', 19, 3, 57.0, 3, 17, '2017-03-01'),
#  (253, 'Chefs SP fish', 20, 19, 350.0, 3, 17, '2017-03-01'),
#  (254, 'Vege Korma', 14, 20, 283.0, 3, 17, '2017-03-01'),
#  (255, 'Potato Bhaji', 14, 1, 14.0, 3, 17, '2017-03-01'),
#  (256, 'Aloo Mattar', 14, 6, 86.0, 3, 17, '2017-03-01'),
#  (257, 'Channa Masala', 14, 6, 86.0, 3, 17, '2017-03-01'),
#  (258, 'Devilled Potato', 14, 6, 86.0, 3, 17, '2017-03-01'),
#  (259, 'Paneer Masala', 15, 5, 78.0, 3, 17, '2017-03-01'),
#  (260, 'Palak Paneer', 15.5, 14, 219.0, 3, 17, '2017-03-01'),
#  (261, 'Butter Paneer', 15, 7, 107.0, 3, 17, '2017-03-01'),
#  (262, 'Cabbage/Potato', 14, 14, 200.0, 3, 17, '2017-03-01'),
#  (263, 'Devilled Cabbage', 14, 3, 42.0, 3, 17, '2017-03-01'),
#  (264, 'Pumpkin', 15, 4, 61.0, 3, 17, '2017-03-01'),
#  (265, 'Dhal', 14, 14, 198.0, 3, 17, '2017-03-01'),
#  (266, 'Parippu', 15, 4, 57.0, 3, 17, '2017-03-01'),
#  (267, 'Dhal Makhani', 15, 3, 45.0, 3, 17, '2017-03-01'),
#  (268, 'Green Bean Garlic', 15, 8, 116.0, 3, 17, '2017-03-01'),
#  (269, 'Potato Masala', 14, 5, 72.0, 3, 17, '2017-03-01'),
#  (270, 'Potato Curry', 14, 5, 71.0, 3, 17, '2017-03-01'),
#  (271, 'Vege Butter Chick', 15, 6, 90.0, 3, 17, '2017-03-01'),
#  (272, 'Veg Chick Vinloo', 16, 3, 46.0, 3, 17, '2017-03-01'),
#  (273, 'Vege St Fry Chick', 15, 2, 30.0, 3, 17, '2017-03-01'),
#  (274, 'Pepper Chicken', 18, 1, 18.0, 3, 17, '2017-03-01'),
#  (275, 'Pepper Beef', 18, 1, 18.0, 3, 17, '2017-03-01'),
#  (276, 'Pepper Lamb', 17, 1, 17.0, 3, 17, '2017-03-01'),
#  (277, 'Pepper K Prawn', 20, 2, 40.0, 3, 17, '2017-03-01'),
#  (278, 'Yellow Rice Medium', 3.5, 47, 187.0, 3, 17, '2017-03-01'),
#  (279, 'White Rice Medium', 4, 31, 108.0, 3, 17, '2017-03-01'),
#  (280, 'Pulao', 7, 10, 74.5, 3, 17, '2017-03-01'),
#  (281, 'Chicken Biryani', 14, 20, 284.5, 3, 17, '2017-03-01'),
#  (282, 'Lamb Biryani', 15.5, 8, 116.5, 3, 17, '2017-03-01'),
#  (283, 'Beef Biryani', 15.5, 2, 29.5, 3, 17, '2017-03-01'),
#  (284, 'Special Fried Rice', 15.5, 19, 272.0, 3, 17, '2017-03-01'),
#  (285, 'Plain Naan', 4, 167, 666.0, 3, 17, '2017-03-01'),
#  (286, 'Garlic Naan', 4.5, 282, 1289.25, 3, 17, '2017-03-01'),
#  (287, 'Chapattis', 1.75, 69, 112.25, 3, 17, '2017-03-01'),
#  (288, 'Parathas', 2, 48, 103.5, 3, 17, '2017-03-01'),
#  (289, 'Pappodums x 4', 3, 86, 242.0, 3, 17, '2017-03-01'),
#  (290, 'Raita', 2.5, 51, 127.5, 3, 17, '2017-03-01'),
#  (291, 'Achar', 3, 7, 20.0, 3, 17, '2017-03-01'),
#  (292, 'Mango Chutney', 2.5, 10, 25.0, 3, 17, '2017-03-01'),
#  (293, 'Laccha', 8, 3, 23.0, 3, 17, '2017-03-01'),
#  (294, 'Almond Kulfi', 3.5, 6, 21.0, 3, 17, '2017-03-01'),
#  (295, 'Mango Kulfi', 3.5, 4, 14.0, 3, 17, '2017-03-01'),
#  (296, 'Curd n Honey', 7, 1, 7.0, 3, 17, '2017-03-01'),
#  (297, 'Plain/Salted Lassi', 4, 2, 8.0, 3, 17, '2017-03-01'),
#  (298, 'Sweet Mango Lassi', 4.5, 14, 63.0, 3, 17, '2017-03-01'),
#  (299, 'Falooda', 7, 3, 21.0, 3, 17, '2017-03-01'),
#  (300, 'Yellow Rice Large', 4.5, 95, 461.5, 3, 17, '2017-03-01'),
#  (301, 'White Rice Large', 4, 52, 229.0, 3, 17, '2017-03-01'),
#  (302, 'Devilled Chicken', 18, 1, 18.0, 3, 17, '2017-03-01'),
#  (303, 'Chilli Squid', 20, 2, 38.0, 3, 17, '2017-03-01'),
#  (304, 'Can drinks', 2.5, 31, 77.5, 3, 17, '2017-03-01'),
#  (305, 'Glass Bottle 300ml', 3.5, 8, 28.0, 3, 17, '2017-03-01'),
#  (306, '1.25L drink', 4.25, 2, 8.5, 3, 17, '2017-03-01'),
#  (307, 'Vege Chk MASALA', 15, 2, 30.0, 3, 17, '2017-03-01'),
#  (308, 'Bottled Water', 2, 3, 6.0, 3, 17, '2017-03-01'),
#  (309, 'upgrade ONE SIZE', 1.5, 25, 37.5, 3, 17, '2017-03-01'),
#  (310, 'upgrade TWO SIZES', 2.75, 17, 46.75, 3, 17, '2017-03-01'),
#  (311, 'Cut Chilli', 1.5, 1, 1.5, 3, 17, '2017-03-01'),
#  (312, 'Devilled Lamb', 17, 2, 36.0, 3, 17, '2017-03-01'),
#  (313, '1000 Spic SFY Chicken', 16, 4, 64.0, 3, 17, '2017-03-01'),
#  (314, '1000 Spic Lamb', 17, 1, 17.0, 3, 17, '2017-03-01'),
#  (315, '1000 Spic K Prawns', 10, 4, 66.0, 3, 17, '2017-03-01'),
#  (316, 'BYO Per Head', 1.5, 68, 102.0, 3, 17, '2017-03-01'),
#  (317, 'Buchet of Ice', 1.5, 7, 10.5, 3, 17, '2017-03-01'),
#  (318, 'With spinach', 1, 3, 3.0, 3, 17, '2017-03-01'),
#  (319, 'Curry Puffs', 6.5, 24, 157.5, 4, 17, '2017-04-01'),
#  (320, 'Large Samosas', 6.5, 23, 162.0, 4, 17, '2017-04-01'),
#  (321, 'Samosas - Vege', 7.5, 21, 157.5, 4, 17, '2017-04-01'),
#  (322, 'Mini Spring Rolls', 7.5, 17, 127.5, 4, 17, '2017-04-01'),
#  (323, 'Curry Samosas', 4, 11, 50.0, 4, 17, '2017-04-01'),
#  (324, 'Onion Bhajia', 5.5, 54, 312.3, 4, 17, '2017-04-01'),
#  (325, 'chicken sticks', 7.5, 12, 97.5, 4, 17, '2017-04-01'),
#  (326, 'chicken strips', 8, 9, 74.0, 4, 17, '2017-04-01'),
#  (327, 'Butter Chicken', 16.5, 183, 3087.5, 4, 17, '2017-04-01'),
#  (328, 'Madras Chicken', 18, 12, 200.0, 4, 17, '2017-04-01'),
#  (329, 'Chicken Korma', 16.5, 34, 574.5, 4, 17, '2017-04-01'),
#  (330, 'CH Tikka Masala', 18, 22, 370.0, 4, 17, '2017-04-01'),
#  (331, 'Chicken Vindaloo', 16, 6, 100.0, 4, 17, '2017-04-01'),
#  (332, 'Mustard Chicken', 16, 15, 262.0, 4, 17, '2017-04-01'),
#  (333, 'Chk In Coconut', 16, 5, 80.0, 4, 17, '2017-04-01'),
#  (334, 'Chicken Jalfrezi', 16, 7, 118.0, 4, 17, '2017-04-01'),
#  (335, 'Chefs SP Chicken.', 16, 6, 100.0, 4, 17, '2017-04-01'),
#  (336, 'Kukulmas Curry', 16, 1, 16.0, 4, 17, '2017-04-01'),
#  (337, 'Rogan Josh', 19, 32, 562.0, 4, 17, '2017-04-01'),
#  (338, 'Palak Gosht', 17.5, 7, 127.0, 4, 17, '2017-04-01'),
#  (339, 'Madras Lamb', 17, 6, 104.0, 4, 17, '2017-04-01'),
#  (340, 'Lamb Korma', 17, 26, 460.0, 4, 17, '2017-04-01'),
#  (341, 'Lamb Vindaloo', 17, 10, 174.0, 4, 17, '2017-04-01'),
#  (342, 'Chefs SP Lamb', 17, 17, 307.0, 4, 17, '2017-04-01'),
#  (343, 'Lamb Masala', 19, 7, 127.0, 4, 17, '2017-04-01'),
#  (344, 'Beef Vindaloo', 16, 15, 250.0, 4, 17, '2017-04-01'),
#  (345, 'Beef Jalfrezi', 16, 8, 136.0, 4, 17, '2017-04-01'),
#  (346, 'Madras Beef', 16, 19, 316.0, 4, 17, '2017-04-01'),
#  (347, 'Moghlai beef', 16, 10, 164.0, 4, 17, '2017-04-01'),
#  (348, 'Beef Korma', 18, 14, 233.0, 4, 17, '2017-04-01'),
#  (349, 'Chefs Sp beef', 18, 13, 218.0, 4, 17, '2017-04-01'),
#  (350, 'Chefs SP Prawn.', 18, 7, 134.0, 4, 17, '2017-04-01'),
#  (351, 'Mixed Seafood', 19, 5, 101.0, 4, 17, '2017-04-01'),
#  (352, 'K Praw N Coconut', 18, 6, 114.0, 4, 17, '2017-04-01'),
#  (353, 'Spicy King Prawn', 20, 6, 118.0, 4, 17, '2017-04-01'),
#  (354, 'Prawn Vindaloo', 20, 1, 20.0, 4, 17, '2017-04-01'),
#  (355, 'Madras Prawn', 18, 4, 72.0, 4, 17, '2017-04-01'),
#  (356, 'Fish in Coconut', 19, 6, 112.0, 4, 17, '2017-04-01'),
#  (357, 'Chefs SP fish', 18, 11, 214.0, 4, 17, '2017-04-01'),
#  (358, 'Vege Korma', 14, 19, 272.0, 4, 17, '2017-04-01'),
#  (359, 'Potato Bhaji', 15, 2, 29.0, 4, 17, '2017-04-01'),
#  (360, 'Aloo Mattar', 15, 5, 72.0, 4, 17, '2017-04-01'),
#  (361, 'Channa Masala', 14, 4, 58.0, 4, 17, '2017-04-01'),
#  (362, 'Devilled Potato', 14, 8, 116.0, 4, 17, '2017-04-01'),
#  (363, 'Paneer Masala', 15, 3, 47.0, 4, 17, '2017-04-01'),
#  (364, 'Palak Paneer', 15.5, 11, 172.0, 4, 17, '2017-04-01'),
#  (365, 'Butter Paneer', 16, 2, 31.0, 4, 17, '2017-04-01'),
#  (366, 'Cabbage/Potato', 15, 7, 100.0, 4, 17, '2017-04-01'),
#  (367, 'Pumpkin', 15, 4, 61.0, 4, 17, '2017-04-01'),
#  (368, 'Dhal', 14, 14, 199.5, 4, 17, '2017-04-01'),
#  (369, 'Parippu', 14, 2, 29.0, 4, 17, '2017-04-01'),
#  (370, 'Dhal Makhani', 15, 2, 30.0, 4, 17, '2017-04-01'),
#  (371, 'Green Bean Garlic', 15, 8, 117.0, 4, 17, '2017-04-01'),
#  (372, 'Potato Masala', 14, 2, 28.0, 4, 17, '2017-04-01'),
#  (373, 'Potato Curry', 14, 6, 87.0, 4, 17, '2017-04-01'),
#  (374, 'Vege Butter Chick', 15, 17, 255.0, 4, 17, '2017-04-01'),
#  (375, 'Veg Chick Vinloo', 15, 2, 30.0, 4, 17, '2017-04-01'),
#  (376, 'Vege St Fry Chick', 15, 4, 60.0, 4, 17, '2017-04-01'),
#  (377, 'Pepper K Prawn', 20, 1, 20.0, 4, 17, '2017-04-01'),
#  (378, 'Yellow Rice Medium', 3.5, 40, 154.0, 4, 17, '2017-04-01'),
#  (379, 'White Rice Medium', 4, 14, 49.0, 4, 17, '2017-04-01'),
#  (380, 'Pulao', 8.5, 17, 126.5, 4, 17, '2017-04-01'),
#  (381, 'Chicken Biryani', 14, 22, 315.5, 4, 17, '2017-04-01'),
#  (382, 'Lamb Biryani', 15.5, 11, 160.0, 4, 17, '2017-04-01'),
#  (383, 'Beef Biryani', 14, 1, 14.0, 4, 17, '2017-04-01'),
#  (384, 'Special Fried Rice', 14, 17, 245.5, 4, 17, '2017-04-01'),
#  (385, 'Plain Naan', 4, 113, 452.0, 4, 17, '2017-04-01'),
#  (386, 'Garlic Naan', 4.5, 254, 1157.75, 4, 17, '2017-04-01'),
#  (387, 'Chapattis', 1.5, 15, 23.0, 4, 17, '2017-04-01'),
#  (388, 'Parathas', 2.5, 31, 68.0, 4, 17, '2017-04-01'),
#  (389, 'Pappodums x 4', 2.75, 56, 156.25, 4, 17, '2017-04-01'),
#  (390, 'Raita', 2.5, 46, 115.0, 4, 17, '2017-04-01'),
#  (391, 'Mango Chutney', 2.5, 10, 25.0, 4, 17, '2017-04-01'),
#  (392, 'Laccha', 7, 1, 7.0, 4, 17, '2017-04-01'),
#  (393, 'Almond Kulfi', 3.5, 5, 17.5, 4, 17, '2017-04-01'),
#  (394, 'Mango Kulfi', 3.5, 5, 18.0, 4, 17, '2017-04-01'),
#  (395, 'Curd n Honey', 7, 1, 7.0, 4, 17, '2017-04-01'),
#  (396, 'Plain/Salted Lassi', 4, 1, 4.0, 4, 17, '2017-04-01'),
#  (397, 'Sweet Mango Lassi', 4, 9, 40.0, 4, 17, '2017-04-01'),
#  (398, 'Chili Naan', 4.75, 1, 4.75, 4, 17, '2017-04-01'),
#  (399, 'Yellow Rice Large', 4.5, 85, 415.5, 4, 17, '2017-04-01'),
#  (400, 'White Rice Large', 4, 49, 217.0, 4, 17, '2017-04-01'),
#  (401, 'Pepper Squid', 20, 1, 20.0, 4, 17, '2017-04-01'),
#  (402, 'Devilled Chicken', 16, 2, 34.0, 4, 17, '2017-04-01'),
#  (403, 'Chilli Squid', 20, 3, 60.0, 4, 17, '2017-04-01'),
#  (404, 'Can drinks', 2.5, 16, 40.0, 4, 17, '2017-04-01'),
#  (405, 'Glass Bottle 300ml', 3.5, 6, 21.0, 4, 17, '2017-04-01'),
#  (406, '1.25L drink', 4.25, 1, 4.25, 4, 17, '2017-04-01'),
#  (407, '2L DRNK', 4.75, 1, 4.75, 4, 17, '2017-04-01'),
#  (408, 'Vege Chk JALFREZI', 15, 1, 15.0, 4, 17, '2017-04-01'),
#  (409, 'upgrade ONE SIZE', 1.5, 23, 34.5, 4, 17, '2017-04-01'),
#  (410, 'upgrade TWO SIZES', 2.75, 14, 38.5, 4, 17, '2017-04-01'),
#  (411, 'Cut Chilli', 1.5, 1, 1.5, 4, 17, '2017-04-01'),
#  (412, 'TEA Per Person', 3, 2, 6.0, 4, 17, '2017-04-01'),
#  (413, 'Devilled Lamb', 17, 1, 17.0, 4, 17, '2017-04-01'),
#  (414, 'Devilled K Prawn', 18, 2, 38.0, 4, 17, '2017-04-01'),
#  (415, '1000 Spic SFY Chicken', 17, 6, 100.0, 4, 17, '2017-04-01'),
#  (416, '1000 Spic Lamb', 17, 1, 17.0, 4, 17, '2017-04-01'),
#  (417, '1000 Spic K Prawns', 20, 5, 100.0, 4, 17, '2017-04-01'),
#  (418, 'BYO Per Head', 1.5, 50, 75.0, 4, 17, '2017-04-01'),
#  (419, 'Buchet of Ice', 1.5, 1, 1.5, 4, 17, '2017-04-01'),
#  (420, 'With spinach', 1, 2, 2.0, 4, 17, '2017-04-01'),
#  (421, 'Curry Puffs', 7, 30, 199.5, 5, 17, '2017-05-01'),
#  (422, 'Large Samosas', 6.5, 36, 242.0, 5, 17, '2017-05-01'),
#  (423, 'Samosas - Vege', 7.5, 28, 255.0, 5, 17, '2017-05-01'),
#  (424, 'Mini Spring Rolls', 7.5, 31, 232.5, 5, 17, '2017-05-01'),
#  (425, 'Curry Samosas', 5, 16, 72.0, 5, 17, '2017-05-01'),
#  (426, 'Onion Bhajia', 5.5, 66, 385.0, 5, 17, '2017-05-01'),
#  (427, 'chicken sticks', 7.5, 14, 114.0, 5, 17, '2017-05-01'),
#  (428, 'chicken strips', 9, 12, 101.0, 5, 17, '2017-05-01'),
#  (429, 'Butter Chicken', 16.5, 223, 3771.5, 5, 17, '2017-05-01'),
#  (430, 'Madras Chicken', 16, 6, 100.0, 5, 17, '2017-05-01'),
#  (431, 'Chicken Korma', 16.5, 33, 553.5, 5, 17, '2017-05-01'),
#  (432, 'CH Tikka Masala', 16, 33, 540.0, 5, 17, '2017-05-01'),
#  (433, 'Chicken Vindaloo', 18, 9, 148.0, 5, 17, '2017-05-01'),
#  (434, 'Mustard Chicken', 18, 36, 612.0, 5, 17, '2017-05-01'),
#  (435, 'Chk In Coconut', 18, 5, 84.0, 5, 17, '2017-05-01'),
#  (436, 'Chicken Jalfrezi', 16, 14, 238.0, 5, 17, '2017-05-01'),
#  (437, 'Chefs SP Chicken.', 16, 8, 132.0, 5, 17, '2017-05-01'),
#  (438, 'Kukulmas Curry', 18, 11, 192.0, 5, 17, '2017-05-01'),
#  (439, 'Rogan Josh', 19, 37, 657.0, 5, 17, '2017-05-01'),
#  (440, 'Palak Gosht', 19, 6, 108.0, 5, 17, '2017-05-01'),
#  (441, 'Madras Lamb', 19, 12, 214.0, 5, 17, '2017-05-01'),
#  (442, 'Lamb Korma', 17, 36, 630.0, 5, 17, '2017-05-01'),
#  (443, 'Lamb Vindaloo', 19, 9, 165.0, 5, 17, '2017-05-01'),
#  (444, 'Chefs SP Lamb', 19, 18, 314.0, 5, 17, '2017-05-01'),
#  (445, 'Lamb Masala', 17, 16, 280.0, 5, 17, '2017-05-01'),
#  (446, 'Beef Vindaloo', 16, 32, 530.0, 5, 17, '2017-05-01'),
#  (447, 'Beef Jalfrezi', 18, 8, 134.0, 5, 17, '2017-05-01'),
#  (448, 'Madras Beef', 18, 27, 446.0, 5, 17, '2017-05-01'),
#  (449, 'Moghlai beef', 16, 11, 182.0, 5, 17, '2017-05-01'),
#  (450, 'Beef Korma', 16, 13, 210.0, 5, 17, '2017-05-01'),
#  (451, 'Chefs Sp beef', 16, 21, 350.0, 5, 17, '2017-05-01'),
#  (452, 'Chefs SP Prawn.', 20, 9, 172.0, 5, 17, '2017-05-01'),
#  (453, 'Mixed Seafood', 21, 2, 42.0, 5, 17, '2017-05-01'),
#  (454, 'K Praw N Coconut', 20, 9, 172.0, 5, 17, '2017-05-01'),
#  (455, 'Spicy King Prawn', 20, 17, 318.0, 5, 17, '2017-05-01'),
#  (456, 'Madras Prawn', 18, 3, 54.0, 5, 17, '2017-05-01'),
#  (457, 'Fish in Coconut', 19, 5, 93.0, 5, 17, '2017-05-01'),
#  (458, 'Chefs SP fish', 20, 4, 78.0, 5, 17, '2017-05-01'),
#  (459, 'Vege Korma', 14, 23, 335.0, 5, 17, '2017-05-01'),
#  (460, 'Potato Bhaji', 14, 6, 85.0, 5, 17, '2017-05-01'),
#  (461, 'Aloo Mattar', 14, 9, 129.0, 5, 17, '2017-05-01'),
#  (462, 'Channa Masala', 15, 8, 114.0, 5, 17, '2017-05-01'),
#  (463, 'Devilled Potato', 14, 6, 86.0, 5, 17, '2017-05-01'),
#  (464, 'Paneer Masala', 15, 4, 60.0, 5, 17, '2017-05-01'),
#  (465, 'Palak Paneer', 16, 20, 313.5, 5, 17, '2017-05-01'),
#  (466, 'Butter Paneer', 15, 13, 200.0, 5, 17, '2017-05-01'),
#  (467, 'Cabbage/Potato', 15, 11, 158.0, 5, 17, '2017-05-01'),
#  (468, 'Devilled Cabbage', 14, 6, 88.0, 5, 17, '2017-05-01'),
#  (469, 'Pumpkin', 16, 9, 138.0, 5, 17, '2017-05-01'),
#  (470, 'Dhal', 14, 19, 270.0, 5, 17, '2017-05-01'),
#  (471, 'Parippu', 15, 9, 132.0, 5, 17, '2017-05-01'),
#  (472, 'Dhal Makhani', 15, 3, 45.0, 5, 17, '2017-05-01'),
#  (473, 'Green Bean Garlic', 15, 8, 117.0, 5, 17, '2017-05-01'),
#  (474, 'Potato Masala', 14, 5, 71.0, 5, 17, '2017-05-01'),
#  (475, 'Potato Curry', 15, 6, 85.0, 5, 17, '2017-05-01'),
#  (476, 'Vege Butter Chick', 15, 14, 214.0, 5, 17, '2017-05-01'),
#  (477, 'Veg Chick Vinloo', 15, 4, 61.0, 5, 17, '2017-05-01'),
#  (478, 'Vege St Fry Chick', 16, 5, 77.0, 5, 17, '2017-05-01'),
#  (479, 'Pepper Chicken', 18, 1, 18.0, 5, 17, '2017-05-01'),
#  (480, 'Pepper Beef', 18, 3, 52.0, 5, 17, '2017-05-01'),
#  (481, 'Yellow Rice Medium', 3.5, 56, 221.0, 5, 17, '2017-05-01'),
#  (482, 'White Rice Medium', 3, 21, 75.0, 5, 17, '2017-05-01'),
#  (483, 'Pulao', 7, 21, 154.5, 5, 17, '2017-05-01'),
#  (484, 'Chicken Biryani', 14, 29, 419.5, 5, 17, '2017-05-01'),
#  (485, 'Lamb Biryani', 15.5, 11, 160.0, 5, 17, '2017-05-01'),
#  (486, 'Beef Biryani', 14, 1, 14.0, 5, 17, '2017-05-01'),
#  (487, 'Special Fried Rice', 15.5, 14, 203.5, 5, 17, '2017-05-01'),
#  (488, 'Plain Naan', 4, 152, 608.0, 5, 17, '2017-05-01'),
#  (489, 'Garlic Naan', 4.5, 306, 1398.25, 5, 17, '2017-05-01'),
#  (490, 'Chapattis', 1.75, 28, 44.5, 5, 17, '2017-05-01'),
#  (491, 'Parathas', 2.5, 51, 110.0, 5, 17, '2017-05-01'),
#  (492, 'Pappodums x 4', 2.75, 125, 351.25, 5, 17, '2017-05-01'),
#  (493, 'Raita', 2.5, 64, 160.0, 5, 17, '2017-05-01'),
#  (494, 'Achar', 3, 1, 3.0, 5, 17, '2017-05-01'),
#  (495, 'Mango Chutney', 2.5, 11, 27.5, 5, 17, '2017-05-01'),
#  (496, 'Laccha', 7, 3, 23.0, 5, 17, '2017-05-01'),
#  (497, 'Ice Cream', 5, 1, 5.0, 5, 17, '2017-05-01'),
#  (498, 'Plain/Salted Lassi', 4, 1, 4.0, 5, 17, '2017-05-01'),
#  (499, 'Sweet Mango Lassi', 4.5, 18, 80.0, 5, 17, '2017-05-01'),
#  (500, 'Falooda', 7, 2, 14.0, 5, 17, '2017-05-01'),
#  (501, 'Chili Naan', 4.75, 1, 4.75, 5, 17, '2017-05-01'),
#  (502, 'Yellow Rice Large', 4.5, 95, 461.5, 5, 17, '2017-05-01'),
#  (503, 'White Rice Large', 5, 75, 320.0, 5, 17, '2017-05-01'),
#  (504, 'Pepper Squid', 18, 1, 18.0, 5, 17, '2017-05-01'),
#  (505, 'Devilled Chicken', 18, 2, 34.0, 5, 17, '2017-05-01'),
#  (506, 'Devilled Beff', 18, 1, 18.0, 5, 17, '2017-05-01'),
#  (507, 'Chilli Squid', 20, 1, 20.0, 5, 17, '2017-05-01'),
#  (508, 'Cheese Nann', 4.75, 4, 19.0, 5, 17, '2017-05-01'),
#  (509, 'Can drinks', 2.5, 31, 77.5, 5, 17, '2017-05-01'),
#  (510, 'Glass Bottle 300ml', 3.5, 5, 17.5, 5, 17, '2017-05-01'),
#  (511, 'Vege Chk MASALA', 15, 1, 15.0, 5, 17, '2017-05-01'),
#  (512, 'Vege Chk JALFREZI', 15, 1, 15.0, 5, 17, '2017-05-01'),
#  (513, 'upgrade ONE SIZE', 1.5, 18, 27.0, 5, 17, '2017-05-01'),
#  (514, 'upgrade TWO SIZES', 2.75, 5, 13.75, 5, 17, '2017-05-01'),
#  (515, 'Cut Chilli', 1.5, 3, 4.5, 5, 17, '2017-05-01'),
#  (516, 'TEA Per Person', 3, 5, 17.0, 5, 17, '2017-05-01'),
#  (517, 'Devilled Lamb', 17, 1, 17.0, 5, 17, '2017-05-01'),
#  (518, 'Devilled K Prawn', 20, 2, 40.0, 5, 17, '2017-05-01'),
#  (519, 'Devilled Fish', 18, 1, 18.0, 5, 17, '2017-05-01'),
#  (520, '1000 Spic SFY Chicken', 16, 7, 115.5, 5, 17, '2017-05-01'),
#  (521, '1000 Spic SRY Beef', 16, 1, 16.0, 5, 17, '2017-05-01'),
#  (522, '1000 Spic K Prawns', 18, 3, 56.0, 5, 17, '2017-05-01'),
#  (523, 'BYO Per Head', 1.5, 50, 83.5, 5, 17, '2017-05-01'),
#  (524, 'Buchet of Ice', 1.5, 4, 6.0, 5, 17, '2017-05-01'),
#  (525, 'With spinach', 1, 5, 5.0, 5, 17, '2017-05-01'),
#  (526, 'Curry Puffs', 6.5, 22, 147.5, 6, 17, '2017-06-01'),
#  (527, 'Large Samosas', 6.5, 13, 88.0, 6, 17, '2017-06-01'),
#  (528, 'Samosas - Vege', 7.5, 15, 180.0, 6, 17, '2017-06-01'),
#  (529, 'Mini Spring Rolls', 7.5, 10, 75.0, 6, 17, '2017-06-01'),
#  (530, 'Curry Samosas', 4, 9, 37.0, 6, 17, '2017-06-01'),
#  (531, 'Onion Bhajia', 5.5, 47, 272.5, 6, 17, '2017-06-01'),
#  (532, 'chicken sticks', 7.5, 11, 90.0, 6, 17, '2017-06-01'),
#  (533, 'chicken strips', 8, 11, 92.0, 6, 17, '2017-06-01'),
#  (534, 'Butter Chicken', 16.5, 139, 2337.0, 6, 17, '2017-06-01'),
#  (535, 'Madras Chicken', 16, 4, 66.0, 6, 17, '2017-06-01'),
#  (536, 'Chicken Korma', 18, 28, 477.0, 6, 17, '2017-06-01'),
#  (537, 'CH Tikka Masala', 18, 18, 300.0, 6, 17, '2017-06-01'),
#  (538, 'Chicken Vindaloo', 16, 5, 82.0, 6, 17, '2017-06-01'),
#  (539, 'Mustard Chicken', 16, 18, 302.0, 6, 17, '2017-06-01'),
#  (540, 'Chk In Coconut', 16, 1, 16.0, 6, 17, '2017-06-01'),
#  (541, 'Chicken Jalfrezi', 16, 6, 100.0, 6, 17, '2017-06-01'),
#  (542, 'Chefs SP Chicken.', 16, 5, 84.0, 6, 17, '2017-06-01'),
#  (543, 'Kukulmas Curry', 18, 4, 68.0, 6, 17, '2017-06-01'),
#  (544, 'Rogan Josh', 17, 20, 346.0, 6, 17, '2017-06-01'),
#  (545, 'Palak Gosht', 19, 6, 106.5, 6, 17, '2017-06-01'),
#  (546, 'Madras Lamb', 17, 5, 89.0, 6, 17, '2017-06-01'),
#  (547, 'Lamb Korma', 17, 24, 424.0, 6, 17, '2017-06-01'),
#  (548, 'Lamb Vindaloo', 17, 5, 87.0, 6, 17, '2017-06-01'),
#  (549, 'Chefs SP Lamb', 19, 14, 254.0, 6, 17, '2017-06-01'),
#  (550, 'Lamb Masala', 17, 12, 220.0, 6, 17, '2017-06-01'),
#  (551, 'Beef Vindaloo', 18, 9, 146.0, 6, 17, '2017-06-01'),
#  (552, 'Beef Jalfrezi', 16, 3, 48.0, 6, 17, '2017-06-01'),
#  (553, 'Madras Beef', 16, 10, 168.0, 6, 17, '2017-06-01'),
#  (554, 'Moghlai beef', 16, 10, 172.0, 6, 17, '2017-06-01'),
#  (555, 'Beef Korma', 16, 13, 212.0, 6, 17, '2017-06-01'),
#  (556, 'Chefs Sp beef', 16, 8, 130.0, 6, 17, '2017-06-01'),
#  (557, 'Chefs SP Prawn.', 20, 1, 20.0, 6, 17, '2017-06-01'),
#  (558, 'Mixed Seafood', 19, 1, 19.0, 6, 17, '2017-06-01'),
#  (559, 'K Praw N Coconut', 20, 4, 74.0, 6, 17, '2017-06-01'),
#  (560, 'Spicy King Prawn', 18, 3, 58.0, 6, 17, '2017-06-01'),
#  (561, 'Prawn Vindaloo', 18, 1, 18.0, 6, 17, '2017-06-01'),
#  (562, 'Madras Prawn', 18, 4, 74.0, 6, 17, '2017-06-01'),
#  (563, 'Fish in Coconut', 19, 2, 38.0, 6, 17, '2017-06-01'),
#  (564, 'Chefs SP fish', 20, 10, 190.0, 6, 17, '2017-06-01'),
#  (565, 'Vege Korma', 14, 7, 99.0, 6, 17, '2017-06-01'),
#  (566, 'Potato Bhaji', 14, 4, 57.0, 6, 17, '2017-06-01'),
#  (567, 'Aloo Mattar', 15, 1, 15.0, 6, 17, '2017-06-01'),
#  (568, 'Channa Masala', 14, 1, 14.0, 6, 17, '2017-06-01'),
#  (569, 'Devilled Potato', 14, 7, 98.0, 6, 17, '2017-06-01'),
#  (570, 'Paneer Masala', 15, 6, 90.0, 6, 17, '2017-06-01'),
#  (571, 'Palak Paneer', 15.5, 11, 173.0, 6, 17, '2017-06-01'),
#  (572, 'Butter Paneer', 15, 6, 90.0, 6, 17, '2017-06-01'),
#  (573, 'Cabbage/Potato', 15, 4, 59.0, 6, 17, '2017-06-01'),
#  (574, 'Devilled Cabbage', 15, 2, 30.0, 6, 17, '2017-06-01'),
#  (575, 'Pumpkin', 15, 2, 30.0, 6, 17, '2017-06-01'),
#  (576, 'Dhal', 14, 7, 101.0, 6, 17, '2017-06-01'),
#  (577, 'Parippu', 15, 2, 29.0, 6, 17, '2017-06-01'),
#  (578, 'Dhal Makhani', 15, 2, 30.0, 6, 17, '2017-06-01'),
#  (579, 'Green Bean Garlic', 14, 7, 100.0, 6, 17, '2017-06-01'),
#  (580, 'Potato Masala', 14, 6, 88.0, 6, 17, '2017-06-01'),
#  (581, 'Potato Curry', 14, 3, 43.0, 6, 17, '2017-06-01'),
#  (582, 'Vege Butter Chick', 15, 9, 136.0, 6, 17, '2017-06-01'),
#  (583, 'Veg Chick Vinloo', 15, 2, 30.0, 6, 17, '2017-06-01'),
#  (584, 'Vege St Fry Chick', 15, 4, 61.0, 6, 17, '2017-06-01'),
#  (585, 'Pepper Beef', 18, 1, 18.0, 6, 17, '2017-06-01'),
#  (586, 'Pepper K Prawn', 20, 1, 20.0, 6, 17, '2017-06-01'),
#  (587, 'Yellow Rice Medium', 3.5, 40, 153.5, 6, 17, '2017-06-01'),
#  (588, 'White Rice Medium', 4, 18, 64.0, 6, 17, '2017-06-01'),
#  (589, 'Pulao', 8.5, 9, 69.0, 6, 17, '2017-06-01'),
#  (590, 'Chicken Biryani', 14, 25, 352.0, 6, 17, '2017-06-01'),
#  (591, 'Lamb Biryani', 14, 6, 87.0, 6, 17, '2017-06-01'),
#  (592, 'Beef Biryani', 14, 4, 56.0, 6, 17, '2017-06-01'),
#  (593, 'Special Fried Rice', 15.5, 13, 189.5, 6, 17, '2017-06-01'),
#  (594, 'Plain Naan', 4, 76, 304.0, 6, 17, '2017-06-01'),
#  (595, 'Garlic Naan', 4.5, 182, 830.25, 6, 17, '2017-06-01'),
#  (596, 'Chapattis', 1.5, 13, 21.25, 6, 17, '2017-06-01'),
#  (597, 'Parathas', 2, 30, 64.0, 6, 17, '2017-06-01'),
#  (598, 'Pappodums x 4', 2.75, 71, 197.75, 6, 17, '2017-06-01'),
#  (599, 'Raita', 2.5, 31, 77.5, 6, 17, '2017-06-01'),
#  (600, 'Achar', 2.5, 1, 2.5, 6, 17, '2017-06-01'),
#  (601, 'Mango Chutney', 2.5, 6, 15.0, 6, 17, '2017-06-01'),
#  (602, 'Laccha', 8, 2, 15.0, 6, 17, '2017-06-01'),
#  (603, 'Almond Kulfi', 3.5, 1, 3.5, 6, 17, '2017-06-01'),
#  (604, 'Mango Kulfi', 3.5, 2, 7.0, 6, 17, '2017-06-01'),
#  (605, 'Sweet Mango Lassi', 4.5, 3, 13.0, 6, 17, '2017-06-01'),
#  (606, 'Falooda', 7, 1, 7.0, 6, 17, '2017-06-01'),
#  (607, 'Yellow Rice Large', 4.5, 65, 312.5, 6, 17, '2017-06-01'),
#  (608, 'White Rice Large', 4, 32, 133.0, 6, 17, '2017-06-01'),
#  (609, 'Pepper Squid', 20, 1, 20.0, 6, 17, '2017-06-01'),
#  (610, 'Devilled Chicken', 16, 3, 48.0, 6, 17, '2017-06-01'),
#  (611, '1000 SPC Squid', 18, 2, 38.0, 6, 17, '2017-06-01'),
#  (612, 'Can drinks', 2.5, 26, 65.0, 6, 17, '2017-06-01'),
#  (613, 'Glass Bottle 300ml', 3.5, 4, 14.0, 6, 17, '2017-06-01'),
#  (614, 'Vege Chk MASALA', 15, 5, 75.0, 6, 17, '2017-06-01'),
#  (615, 'Vege Chk JALFREZI', 15, 1, 15.0, 6, 17, '2017-06-01'),
#  (616, 'upgrade ONE SIZE', 1.5, 14, 21.0, 6, 17, '2017-06-01'),
#  (617, 'upgrade TWO SIZES', 2.75, 4, 11.0, 6, 17, '2017-06-01'),
#  (618, 'TEA Per Person', 10, 2, 20.0, 6, 17, '2017-06-01'),
#  (619, 'Devilled K Prawn', 20, 1, 20.0, 6, 17, '2017-06-01'),
#  (620, '1000 Spic SFY Chicken', 16, 5, 83.0, 6, 17, '2017-06-01'),
#  (621, '1000 Spic SRY Beef', 16, 1, 16.0, 6, 17, '2017-06-01'),
#  (622, '1000 Spic K Prawns', 18, 2, 38.0, 6, 17, '2017-06-01'),
#  (623, 'BYO Per Head', 1.5, 25, 36.5, 6, 17, '2017-06-01'),
#  (624, 'Buchet of Ice', 1.5, 2, 3.0, 6, 17, '2017-06-01'),
#  (625, 'With spinach', 1, 1, 1.0, 6, 17, '2017-06-01'),
#  (626, 'Curry Puffs', 6.5, 22, 148.0, 7, 17, '2017-07-01'),
#  (627, 'Large Samosas', 7, 26, 177.75, 7, 17, '2017-07-01'),
#  (628, 'Samosas - Vege', 7.5, 23, 172.5, 7, 17, '2017-07-01'),
#  (629, 'Mini Spring Rolls', 7.5, 17, 127.5, 7, 17, '2017-07-01'),
#  (630, 'Curry Samosas', 4, 21, 91.0, 7, 17, '2017-07-01'),
#  (631, 'Onion Bhajia', 5.5, 77, 441.0, 7, 17, '2017-07-01'),
#  (632, 'chicken sticks', 9, 12, 103.5, 7, 17, '2017-07-01'),
#  (633, 'chicken strips', 9, 13, 110.0, 7, 17, '2017-07-01'),
#  (634, 'Butter Chicken', 16.5, 236, 3988.0, 7, 17, '2017-07-01'),
#  (635, 'Madras Chicken', 16, 12, 199.0, 7, 17, '2017-07-01'),
#  (636, 'Chicken Korma', 16.5, 36, 603.0, 7, 17, '2017-07-01'),
#  (637, 'CH Tikka Masala', 18, 36, 600.0, 7, 17, '2017-07-01'),
#  (638, 'Chicken Vindaloo', 16, 13, 216.0, 7, 17, '2017-07-01'),
#  (639, 'Mustard Chicken', 18, 33, 564.0, 7, 17, '2017-07-01'),
#  (640, 'Chk In Coconut', 16, 5, 82.0, 7, 17, '2017-07-01'),
#  (641, 'Chicken Jalfrezi', 16, 12, 198.0, 7, 17, '2017-07-01'),
#  (642, 'Chefs SP Chicken.', 16, 7, 118.0, 7, 17, '2017-07-01'),
#  (643, 'Kukulmas Curry', 18, 9, 156.0, 7, 17, '2017-07-01'),
#  (644, 'Rogan Josh', 17, 33, 581.0, 7, 17, '2017-07-01'),
#  (645, 'Palak Gosht', 17.5, 9, 159.0, 7, 17, '2017-07-01'),
#  (646, 'Madras Lamb', 17, 17, 301.0, 7, 17, '2017-07-01'),
#  (647, 'Lamb Korma', 17, 34, 602.0, 7, 17, '2017-07-01'),
#  (648, 'Lamb Vindaloo', 17, 11, 201.0, 7, 17, '2017-07-01'),
#  (649, 'Chefs SP Lamb', 17, 18, 326.0, 7, 17, '2017-07-01'),
#  (650, 'Lamb Masala', 17, 20, 362.0, 7, 17, '2017-07-01'),
#  (651, 'Beef Vindaloo', 16, 28, 458.0, 7, 17, '2017-07-01'),
#  (652, 'Beef Jalfrezi', 16, 13, 216.0, 7, 17, '2017-07-01'),
#  (653, 'Madras Beef', 16, 23, 384.0, 7, 17, '2017-07-01'),
#  (654, 'Moghlai beef', 18, 9, 156.0, 7, 17, '2017-07-01'),
#  (655, 'Beef Korma', 16, 22, 366.0, 7, 17, '2017-07-01'),
#  (656, 'Chefs Sp beef', 16, 7, 120.0, 7, 17, '2017-07-01'),
#  (657, 'Chefs SP Prawn.', 20, 10, 196.0, 7, 17, '2017-07-01'),
#  (658, 'Mixed Seafood', 19, 7, 143.0, 7, 17, '2017-07-01'),
#  (659, 'K Praw N Coconut', 20, 9, 170.0, 7, 17, '2017-07-01'),
#  (660, 'Spicy King Prawn', 18, 13, 252.0, 7, 17, '2017-07-01'),
#  (661, 'Prawn Vindaloo', 20, 3, 58.0, 7, 17, '2017-07-01'),
#  (662, 'Madras Prawn', 18, 2, 36.0, 7, 17, '2017-07-01'),
#  (663, 'Fish in Coconut', 19, 2, 38.0, 7, 17, '2017-07-01'),
#  (664, 'Chefs SP fish', 18, 12, 230.0, 7, 17, '2017-07-01'),
#  (665, 'Vege Korma', 14, 17, 245.0, 7, 17, '2017-07-01'),
#  (666, 'Potato Bhaji', 14, 2, 29.0, 7, 17, '2017-07-01'),
#  (667, 'Aloo Mattar', 15, 5, 73.0, 7, 17, '2017-07-01'),
#  (668, 'Channa Masala', 14, 6, 86.0, 7, 17, '2017-07-01'),
#  (669, 'Devilled Potato', 15, 9, 129.0, 7, 17, '2017-07-01'),
#  (670, 'Paneer Masala', 16, 8, 124.0, 7, 17, '2017-07-01'),
#  (671, 'Palak Paneer', 15.5, 27, 424.5, 7, 17, '2017-07-01'),
#  (672, 'Butter Paneer', 16, 4, 62.0, 7, 17, '2017-07-01'),
#  (673, 'Cabbage/Potato', 15, 12, 173.0, 7, 17, '2017-07-01'),
#  (674, 'Devilled Cabbage', 15, 1, 15.0, 7, 17, '2017-07-01'),
#  (675, 'Pumpkin', 15, 8, 123.0, 7, 17, '2017-07-01'),
#  (676, 'Dhal', 15, 17, 246.0, 7, 17, '2017-07-01'),
#  (677, 'Parippu', 14, 3, 43.0, 7, 17, '2017-07-01'),
#  (678, 'Dhal Makhani', 15, 5, 75.0, 7, 17, '2017-07-01'),
#  (679, 'Green Bean Garlic', 15, 10, 146.0, 7, 17, '2017-07-01'),
#  (680, 'Potato Masala', 14, 6, 86.0, 7, 17, '2017-07-01'),
#  (681, 'Potato Curry', 14, 7, 99.0, 7, 17, '2017-07-01'),
#  (682, 'Vege Butter Chick', 15, 9, 136.0, 7, 17, '2017-07-01'),
#  (683, 'Veg Chick Vinloo', 16, 1, 16.0, 7, 17, '2017-07-01'),
#  (684, 'Vege St Fry Chick', 15, 5, 77.0, 7, 17, '2017-07-01'),
#  (685, 'Pepper Beef', 16, 2, 34.0, 7, 17, '2017-07-01'),
#  (686, 'Yellow Rice Medium', 3.5, 63, 250.5, 7, 17, '2017-07-01'),
#  (687, 'White Rice Medium', 3, 38, 133.0, 7, 17, '2017-07-01'),
#  (688, 'Pulao', 7, 15, 115.5, 7, 17, '2017-07-01'),
#  (689, 'Chicken Biryani', 15.5, 19, 278.0, 7, 17, '2017-07-01'),
#  (690, 'Lamb Biryani', 14, 12, 175.5, 7, 17, '2017-07-01'),
#  (691, 'Beef Biryani', 14, 2, 28.0, 7, 17, '2017-07-01'),
#  (692, 'Special Fried Rice', 14, 10, 144.5, 7, 17, '2017-07-01'),
#  (693, 'Plain Naan', 4, 168, 673.0, 7, 17, '2017-07-01'),
#  (694, 'Garlic Naan', 4.5, 319, 1463.5, 7, 17, '2017-07-01'),
#  (695, 'juice (glass of)', 4.5, 1, 4.5, 7, 17, '2017-07-01'),
#  (696, 'Chapattis', 1.5, 92, 140.5, 7, 17, '2017-07-01'),
#  (697, 'Parathas', 2, 46, 98.0, 7, 17, '2017-07-01'),
#  (698, 'Pappodums x 4', 2.75, 107, 301.25, 7, 17, '2017-07-01'),
#  (699, 'Raita', 2.5, 42, 105.0, 7, 17, '2017-07-01'),
#  (700, 'Achar', 3, 3, 8.0, 7, 17, '2017-07-01'),
#  (701, 'Mango Chutney', 2.5, 5, 12.5, 7, 17, '2017-07-01'),
#  (702, 'Laccha', 7, 6, 43.0, 7, 17, '2017-07-01'),
#  (703, 'Almond Kulfi', 3.5, 2, 7.0, 7, 17, '2017-07-01'),
#  (704, 'Mango Kulfi', 3.5, 4, 14.5, 7, 17, '2017-07-01'),
#  (705, 'Ice Cream', 5, 1, 5.0, 7, 17, '2017-07-01'),
#  (706, 'Plain/Salted Lassi', 4, 4, 16.0, 7, 17, '2017-07-01'),
#  (707, 'Sweet Mango Lassi', 4.5, 17, 75.0, 7, 17, '2017-07-01'),
#  (708, 'Falooda', 7, 1, 7.0, 7, 17, '2017-07-01'),
#  (709, 'Yellow Rice Large', 4.5, 111, 532.0, 7, 17, '2017-07-01'),
#  (710, 'White Rice Large', 4, 72, 315.0, 7, 17, '2017-07-01'),
#  (711, 'Devilled Chicken', 16, 1, 16.0, 7, 17, '2017-07-01'),
#  (712, 'Devilled Beff', 16, 1, 16.0, 7, 17, '2017-07-01'),
#  (713, 'Chilli Squid', 20, 2, 40.0, 7, 17, '2017-07-01'),
#  (714, '1000 SPC Squid', 20, 1, 20.0, 7, 17, '2017-07-01'),
#  (715, 'Cheese Nann', 4.75, 3, 14.25, 7, 17, '2017-07-01'),
#  (716, 'Coconut Water 500ml', 4.75, 1, 4.75, 7, 17, '2017-07-01'),
#  (717, 'Can drinks', 2.5, 24, 60.0, 7, 17, '2017-07-01'),
#  (718, 'Glass Bottle 300ml', 3.5, 6, 21.0, 7, 17, '2017-07-01'),
#  (719, '1.25L drink', 4.25, 2, 8.5, 7, 17, '2017-07-01'),
#  (720, 'Vege Chk MASALA', 15, 2, 30.0, 7, 17, '2017-07-01'),
#  (721, 'BYO', 1.5, 2, 3.0, 7, 17, '2017-07-01'),
#  (722, 'upgrade ONE SIZE', 1.5, 28, 42.0, 7, 17, '2017-07-01'),
#  (723, 'upgrade TWO SIZES', 2.75, 10, 27.5, 7, 17, '2017-07-01'),
#  (724, 'TEA Per Person', 3, 10, 33.0, 7, 17, '2017-07-01'),
#  (725, 'Cup Of Coffee', 4.5, 1, 4.5, 7, 17, '2017-07-01'),
#  (726, 'Devilled Lamb', 19, 2, 36.0, 7, 17, '2017-07-01'),
#  (727, 'Devilled K Prawn', 20, 1, 20.0, 7, 17, '2017-07-01'),
#  (728, '1000 Spic SFY Chicken', 16, 12, 206.0, 7, 17, '2017-07-01'),
#  (729, '1000 Spic Lamb', 19, 1, 19.0, 7, 17, '2017-07-01'),
#  (730, '1000 Spic K Prawns', 20, 2, 40.0, 7, 17, '2017-07-01'),
#  (731, 'BYO Per Head', 1.5, 69, 114.0, 7, 17, '2017-07-01'),
#  (732, 'Buchet of Ice', 1.5, 4, 15.0, 7, 17, '2017-07-01'),
#  (733, 'With spinach', 1, 2, 2.0, 7, 17, '2017-07-01'),
#  (734, 'Curry Puffs', 6.5, 32, 219.33, 8, 17, '2017-08-01'),
#  (735, 'Large Samosas', 6.5, 26, 173.5, 8, 17, '2017-08-01'),
#  (736, 'Samosas - Vege', 7.5, 24, 180.0, 8, 17, '2017-08-01'),
#  (737, 'Mini Spring Rolls', 7.5, 20, 150.0, 8, 17, '2017-08-01'),
#  (738, 'Curry Samosas', 4, 16, 72.0, 8, 17, '2017-08-01'),
#  (739, 'Onion Bhajia', 5.5, 59, 337.5, 8, 17, '2017-08-01'),
#  (740, 'chicken sticks', 7.5, 14, 114.0, 8, 17, '2017-08-01'),
#  (741, 'chicken strips', 8, 18, 152.0, 8, 17, '2017-08-01'),
#  (742, 'Butter Chicken', 16.5, 240, 4044.0, 8, 17, '2017-08-01'),
#  (743, 'Madras Chicken', 16, 12, 198.0, 8, 17, '2017-08-01'),
#  (744, 'Chicken Korma', 16.5, 23, 384.0, 8, 17, '2017-08-01'),
#  (745, 'CH Tikka Masala', 16, 29, 480.0, 8, 17, '2017-08-01'),
#  (746, 'Chicken Vindaloo', 16, 6, 96.0, 8, 17, '2017-08-01'),
#  (747, 'Mustard Chicken', 18, 36, 606.0, 8, 17, '2017-08-01'),
#  (748, 'Chk In Coconut', 16, 12, 202.0, 8, 17, '2017-08-01'),
#  (749, 'Chicken Jalfrezi', 16, 3, 50.0, 8, 17, '2017-08-01'),
#  (750, 'Chefs SP Chicken.', 18, 12, 208.0, 8, 17, '2017-08-01'),
#  (751, 'Kukulmas Curry', 16, 10, 172.0, 8, 17, '2017-08-01'),
#  (752, 'Rogan Josh', 17, 47, 813.0, 8, 17, '2017-08-01'),
#  (753, 'Palak Gosht', 17.5, 3, 55.5, 8, 17, '2017-08-01'),
#  (754, 'Madras Lamb', 19, 9, 157.0, 8, 17, '2017-08-01'),
#  (755, 'Lamb Korma', 17, 45, 797.0, 8, 17, '2017-08-01'),
#  (756, 'Lamb Vindaloo', 17, 12, 214.0, 8, 17, '2017-08-01'),
#  (757, 'Chefs SP Lamb', 17, 21, 367.0, 8, 17, '2017-08-01'),
#  (758, 'Lamb Masala', 19, 14, 256.0, 8, 17, '2017-08-01'),
#  (759, 'Beef Vindaloo', 16, 28, 464.0, 8, 17, '2017-08-01'),
#  (760, 'Beef Jalfrezi', 18, 5, 84.0, 8, 17, '2017-08-01'),
#  (761, 'Madras Beef', 16, 23, 388.0, 8, 17, '2017-08-01'),
#  (762, 'Moghlai beef', 16, 12, 200.0, 8, 17, '2017-08-01'),
#  (763, 'Beef Korma', 16, 18, 298.0, 8, 17, '2017-08-01'),
#  (764, 'Chefs Sp beef', 16, 16, 260.0, 8, 17, '2017-08-01'),
#  (765, 'Chefs SP Prawn.', 18, 7, 134.0, 8, 17, '2017-08-01'),
#  (766, 'Mixed Seafood', 19, 6, 120.0, 8, 17, '2017-08-01'),
#  (767, 'K Praw N Coconut', 18, 8, 146.0, 8, 17, '2017-08-01'),
#  (768, 'Spicy King Prawn', 18, 14, 262.0, 8, 17, '2017-08-01'),
#  (769, 'Prawn Vindaloo', 18, 1, 18.0, 8, 17, '2017-08-01'),
#  (770, 'Madras Prawn', 18, 2, 38.0, 8, 17, '2017-08-01'),
#  (771, 'Fish in Coconut', 19, 3, 53.0, 8, 17, '2017-08-01'),
#  (772, 'Chefs SP fish', 18, 12, 228.0, 8, 17, '2017-08-01'),
#  (773, 'Vege Korma', 14, 15, 214.0, 8, 17, '2017-08-01'),
#  (774, 'Potato Bhaji', 14, 10, 142.0, 8, 17, '2017-08-01'),
#  (775, 'Aloo Mattar', 14, 3, 43.0, 8, 17, '2017-08-01'),
#  (776, 'Channa Masala', 14, 4, 58.0, 8, 17, '2017-08-01'),
#  (777, 'Devilled Potato', 14, 6, 86.0, 8, 17, '2017-08-01'),
#  (778, 'Paneer Masala', 15, 5, 75.0, 8, 17, '2017-08-01'),
#  (779, 'Palak Paneer', 15.5, 14, 218.0, 8, 17, '2017-08-01'),
#  (780, 'Butter Paneer', 15, 7, 106.0, 8, 17, '2017-08-01'),
#  (781, 'Cabbage/Potato', 14, 9, 129.0, 8, 17, '2017-08-01'),
#  (782, 'Devilled Cabbage', 14, 5, 73.0, 8, 17, '2017-08-01'),
#  (783, 'Pumpkin', 15, 6, 92.0, 8, 17, '2017-08-01'),
#  (784, 'Dhal', 14, 20, 287.0, 8, 17, '2017-08-01'),
#  (785, 'Parippu', 15, 3, 44.0, 8, 17, '2017-08-01'),
#  (786, 'Dhal Makhani', 15, 2, 30.0, 8, 17, '2017-08-01'),
#  (787, 'Green Bean Garlic', 15, 6, 87.0, 8, 17, '2017-08-01'),
#  (788, 'Potato Masala', 14, 11, 155.0, 8, 17, '2017-08-01'),
#  (789, 'Potato Curry', 15, 5, 71.0, 8, 17, '2017-08-01'),
#  (790, 'Vege Butter Chick', 15, 13, 196.0, 8, 17, '2017-08-01'),
#  (791, 'Veg Chick Vinloo', 16, 4, 61.0, 8, 17, '2017-08-01'),
#  (792, 'Vege St Fry Chick', 15, 4, 62.0, 8, 17, '2017-08-01'),
#  (793, 'Pepper Chicken', 16, 1, 16.0, 8, 17, '2017-08-01'),
#  (794, 'Pepper Beef', 16, 1, 16.0, 8, 17, '2017-08-01'),
#  (795, 'Yellow Rice Medium', 3.5, 53, 210.5, 8, 17, '2017-08-01'),
#  (796, 'White Rice Medium', 3, 32, 108.0, 8, 17, '2017-08-01'),
#  (797, 'Pulao', 8.5, 10, 77.5, 8, 17, '2017-08-01'),
#  (798, 'Chicken Biryani', 14, 36, 517.5, 8, 17, '2017-08-01'),
#  (799, 'Lamb Biryani', 14, 12, 171.0, 8, 17, '2017-08-01'),
#  (800, 'Beef Biryani', 14, 2, 29.5, 8, 17, '2017-08-01'),
#  (801, 'Special Fried Rice', 14, 17, 241.0, 8, 17, '2017-08-01'),
#  (802, 'Plain Naan', 4, 134, 536.0, 8, 17, '2017-08-01'),
#  (803, 'Garlic Naan', 4.5, 321, 1464.75, 8, 17, '2017-08-01'),
#  (804, 'Chapattis', 1.5, 45, 70.5, 8, 17, '2017-08-01'),
#  (805, 'Parathas', 2, 41, 91.5, 8, 17, '2017-08-01'),
#  (806, 'Pappodums x 4', 2.75, 115, 324.0, 8, 17, '2017-08-01'),
#  (807, 'Raita', 2.5, 38, 95.0, 8, 17, '2017-08-01'),
#  (808, 'Achar', 2.5, 2, 5.0, 8, 17, '2017-08-01'),
#  (809, 'Mango Chutney', 2.5, 11, 27.5, 8, 17, '2017-08-01'),
#  (810, 'Laccha', 8, 1, 8.0, 8, 17, '2017-08-01'),
#  (811, 'Almond Kulfi', 3.5, 1, 3.5, 8, 17, '2017-08-01'),
#  (812, 'Mango Kulfi', 3.5, 3, 10.5, 8, 17, '2017-08-01'),
#  (813, 'Ice Cream', 5, 1, 5.0, 8, 17, '2017-08-01'),
#  (814, 'Sweet Mango Lassi', 4.5, 5, 21.5, 8, 17, '2017-08-01'),
#  (815, 'Falooda', 7, 1, 7.0, 8, 17, '2017-08-01'),
#  (816, 'Yellow Rice Large', 4.5, 113, 542.5, 8, 17, '2017-08-01'),
#  (817, 'White Rice Large', 4, 70, 297.0, 8, 17, '2017-08-01'),
#  (818, 'Devilled Chicken', 16, 5, 82.0, 8, 17, '2017-08-01'),
#  (819, 'Devilled Beff', 18, 1, 18.0, 8, 17, '2017-08-01'),
#  (820, 'Chilli Squid', 20, 2, 40.0, 8, 17, '2017-08-01'),
#  (821, 'Cheese Nann', 4.75, 6, 28.5, 8, 17, '2017-08-01'),
#  (822, 'Can drinks', 2.5, 22, 55.0, 8, 17, '2017-08-01'),
#  (823, 'Glass Bottle 300ml', 3.5, 6, 21.0, 8, 17, '2017-08-01'),
#  (824, 'Vege Chk MASALA', 15, 1, 15.0, 8, 17, '2017-08-01'),
#  (825, 'Bottled Water', 2, 3, 6.0, 8, 17, '2017-08-01'),
#  (826, 'upgrade ONE SIZE', 2, 37, 56.0, 8, 17, '2017-08-01'),
#  (827, 'upgrade TWO SIZES', 2.75, 4, 11.0, 8, 17, '2017-08-01'),
#  (828, 'Cut Chilli', 1.5, 1, 1.5, 8, 17, '2017-08-01'),
#  (829, 'TEA Per Person', 3, 3, 9.5, 8, 17, '2017-08-01'),
#  (830, '1000 Spic SFY Chicken', 18, 6, 102.0, 8, 17, '2017-08-01'),
#  (831, '1000 Spic K Prawns', 20, 3, 58.0, 8, 17, '2017-08-01'),
#  (832, 'BYO Per Head', 6, 63, 108.0, 8, 17, '2017-08-01'),
#  (833, 'Buchet of Ice', 1.5, 3, 9.0, 8, 17, '2017-08-01'),
#  (834, 'With spinach', 1, 2, 2.0, 8, 17, '2017-08-01'),
#  (835, 'Curry Puffs', 6.5, 31, 206.5, 9, 17, '2017-09-01'),
#  (836, 'Large Samosas', 6.5, 24, 161.0, 9, 17, '2017-09-01'),
#  (837, 'Samosas - Vege', 7.5, 23, 172.5, 9, 17, '2017-09-01'),
#  (838, 'Mini Spring Rolls', 7.5, 13, 97.5, 9, 17, '2017-09-01'),
#  (839, 'Curry Samosas', 5, 9, 40.0, 9, 17, '2017-09-01'),
#  (840, 'Onion Bhajia', 5.5, 57, 330.5, 9, 17, '2017-09-01'),
#  (841, 'chicken sticks', 9, 16, 132.0, 9, 17, '2017-09-01'),
#  (842, 'chicken strips', 9, 15, 127.0, 9, 17, '2017-09-01'),
#  (843, 'Butter Chicken', 16.5, 216, 3652.0, 9, 17, '2017-09-01'),
#  (844, 'Madras Chicken', 16, 8, 128.0, 9, 17, '2017-09-01'),
#  (845, 'Chicken Korma', 18, 38, 643.5, 9, 17, '2017-09-01'),
#  (846, 'CH Tikka Masala', 18, 36, 602.0, 9, 17, '2017-09-01'),
#  (847, 'Chicken Vindaloo', 16, 6, 100.0, 9, 17, '2017-09-01'),
#  (848, 'Mustard Chicken', 18, 25, 426.0, 9, 17, '2017-09-01'),
#  (849, 'Chk In Coconut', 18, 9, 154.0, 9, 17, '2017-09-01'),
#  (850, 'Chicken Jalfrezi', 16, 10, 166.0, 9, 17, '2017-09-01'),
#  (851, 'Chefs SP Chicken.', 16, 13, 218.0, 9, 17, '2017-09-01'),
#  (852, 'Kukulmas Curry', 16, 12, 202.0, 9, 17, '2017-09-01'),
#  (853, 'Rogan Josh', 19, 39, 677.0, 9, 17, '2017-09-01'),
#  (854, 'Palak Gosht', 17.5, 11, 194.0, 9, 17, '2017-09-01'),
#  (855, 'Madras Lamb', 17, 11, 195.0, 9, 17, '2017-09-01'),
#  (856, 'Lamb Korma', 17, 45, 791.0, 9, 17, '2017-09-01'),
#  (857, 'Lamb Vindaloo', 17, 12, 214.0, 9, 17, '2017-09-01'),
#  (858, 'Chefs SP Lamb', 17, 25, 461.0, 9, 17, '2017-09-01'),
#  (859, 'Lamb Masala', 19, 18, 326.0, 9, 17, '2017-09-01'),
#  (860, 'Beef Vindaloo', 18, 23, 382.0, 9, 17, '2017-09-01'),
#  (861, 'Beef Jalfrezi', 16, 5, 84.0, 9, 17, '2017-09-01'),
#  (862, 'Madras Beef', 18, 22, 366.0, 9, 17, '2017-09-01'),
#  (863, 'Moghlai beef', 16, 7, 120.0, 9, 17, '2017-09-01'),
#  (864, 'Beef Korma', 18, 19, 316.0, 9, 17, '2017-09-01'),
#  (865, 'Chefs Sp beef', 16, 12, 198.0, 9, 17, '2017-09-01'),
#  (866, 'Chefs SP Prawn.', 18, 6, 112.0, 9, 17, '2017-09-01'),
#  (867, 'Mixed Seafood', 21, 6, 120.0, 9, 17, '2017-09-01'),
#  (868, 'K Praw N Coconut', 20, 11, 214.0, 9, 17, '2017-09-01'),
#  (869, 'Spicy King Prawn', 20, 13, 252.0, 9, 17, '2017-09-01'),
#  (870, 'Prawn Vindaloo', 18, 2, 38.0, 9, 17, '2017-09-01'),
#  (871, 'Madras Prawn', 20, 2, 40.0, 9, 17, '2017-09-01'),
#  (872, 'Fish in Coconut', 19, 1, 19.0, 9, 17, '2017-09-01'),
#  (873, 'Chefs SP fish', 20, 11, 216.0, 9, 17, '2017-09-01'),
#  (874, 'Vege Korma', 14, 18, 260.0, 9, 17, '2017-09-01'),
#  (875, 'Potato Bhaji', 14, 3, 42.0, 9, 17, '2017-09-01'),
#  (876, 'Aloo Mattar', 15, 7, 103.0, 9, 17, '2017-09-01'),
#  (877, 'Channa Masala', 14, 3, 43.0, 9, 17, '2017-09-01'),
#  (878, 'Devilled Potato', 14, 4, 58.0, 9, 17, '2017-09-01'),
#  (879, 'Paneer Masala', 15, 6, 90.0, 9, 17, '2017-09-01'),
#  (880, 'Palak Paneer', 16, 18, 282.5, 9, 17, '2017-09-01'),
#  (881, 'Butter Paneer', 16, 4, 62.0, 9, 17, '2017-09-01'),
#  (882, 'Cabbage/Potato', 14, 14, 202.0, 9, 17, '2017-09-01'),
#  (883, 'Devilled Cabbage', 15, 3, 43.0, 9, 17, '2017-09-01'),
#  (884, 'Pumpkin', 15, 6, 92.0, 9, 17, '2017-09-01'),
#  (885, 'Dhal', 14, 20, 284.0, 9, 17, '2017-09-01'),
#  (886, 'Parippu', 15, 4, 60.0, 9, 17, '2017-09-01'),
#  (887, 'Dhal Makhani', 15, 7, 105.0, 9, 17, '2017-09-01'),
#  (888, 'Green Bean Garlic', 15, 6, 90.0, 9, 17, '2017-09-01'),
#  (889, 'Potato Masala', 14, 5, 71.0, 9, 17, '2017-09-01'),
#  (890, 'Potato Curry', 14, 3, 42.0, 9, 17, '2017-09-01'),
#  (891, 'Vege Butter Chick', 15, 14, 211.0, 9, 17, '2017-09-01'),
#  (892, 'Veg Chick Vinloo', 15, 2, 30.0, 9, 17, '2017-09-01'),
#  (893, 'Vege St Fry Chick', 15, 5, 76.0, 9, 17, '2017-09-01'),
#  (894, 'Pepper Beef', 16, 1, 16.0, 9, 17, '2017-09-01'),
#  (895, 'Yellow Rice Medium', 3.5, 49, 193.5, 9, 17, '2017-09-01'),
#  (896, 'White Rice Medium', 3, 32, 112.0, 9, 17, '2017-09-01'),
#  (897, 'Pulao', 8.5, 17, 134.0, 9, 17, '2017-09-01'),
#  (898, 'Chicken Biryani', 14, 27, 385.5, 9, 17, '2017-09-01'),
#  (899, 'Lamb Biryani', 15.5, 13, 195.5, 9, 17, '2017-09-01'),
#  (900, 'Beef Biryani', 14, 1, 14.0, 9, 17, '2017-09-01'),
#  (901, 'Special Fried Rice', 14, 13, 186.5, 9, 17, '2017-09-01'),
#  (902, 'Plain Naan', 4, 201, 804.0, 9, 17, '2017-09-01'),
#  (903, 'Garlic Naan', 4.5, 266, 1221.5, 9, 17, '2017-09-01'),
#  (904, 'Chapattis', 1.75, 38, 61.25, 9, 17, '2017-09-01'),
#  (905, 'Parathas', 2, 34, 71.5, 9, 17, '2017-09-01'),
#  (906, 'Pappodums x 4', 2.75, 110, 310.0, 9, 17, '2017-09-01'),
#  (907, 'Raita', 2.5, 47, 117.5, 9, 17, '2017-09-01'),
#  (908, 'Achar', 3, 6, 15.5, 9, 17, '2017-09-01'),
#  (909, 'Mango Chutney', 2.5, 8, 20.0, 9, 17, '2017-09-01'),
#  (910, 'Laccha', 7, 2, 15.0, 9, 17, '2017-09-01'),
#  (911, 'Almond Kulfi', 3.5, 6, 21.0, 9, 17, '2017-09-01'),
#  (912, 'Mango Kulfi', 3.5, 6, 21.0, 9, 17, '2017-09-01'),
#  (913, 'Ice Cream', 5, 1, 5.0, 9, 17, '2017-09-01'),
#  (914, 'Plain/Salted Lassi', 4, 2, 8.0, 9, 17, '2017-09-01'),
#  (915, 'Sweet Mango Lassi', 4, 12, 52.0, 9, 17, '2017-09-01'),
#  (916, 'Mango Nectar', 7, 2, 14.0, 9, 17, '2017-09-01'),
#  (917, 'Falooda', 7, 5, 35.0, 9, 17, '2017-09-01'),
#  (918, 'Yellow Rice Large', 4.5, 104, 503.0, 9, 17, '2017-09-01'),
#  (919, 'White Rice Large', 4, 73, 318.0, 9, 17, '2017-09-01'),
#  (920, 'Pepper Squid', 20, 1, 20.0, 9, 17, '2017-09-01'),
#  (921, 'Devilled Beff', 16, 2, 34.0, 9, 17, '2017-09-01'),
#  (922, 'Chilli Squid', 20, 1, 20.0, 9, 17, '2017-09-01'),
#  (923, 'Cheese Nann', 4.75, 3, 14.75, 9, 17, '2017-09-01'),
#  (924, 'Can drinks', 2.5, 25, 62.5, 9, 17, '2017-09-01'),
#  (925, 'Glass Bottle 300ml', 3.5, 6, 21.0, 9, 17, '2017-09-01'),
#  (926, '1.25L drink', 4.25, 1, 4.25, 9, 17, '2017-09-01'),
#  (927, 'Vege Chk MASALA', 15, 2, 30.0, 9, 17, '2017-09-01'),
#  (928, 'upgrade ONE SIZE', 1.5, 24, 36.0, 9, 17, '2017-09-01'),
#  (929, 'upgrade TWO SIZES', 2.75, 11, 30.25, 9, 17, '2017-09-01'),
#  (930, 'Cut Chilli', 1.5, 2, 3.0, 9, 17, '2017-09-01'),
#  (931, 'Devilled K Prawn', 20, 1, 20.0, 9, 17, '2017-09-01'),
#  (932, 'Devilled Squid', 20, 1, 20.0, 9, 17, '2017-09-01'),
#  (933, '1000 Spic SFY Chicken', 16, 6, 100.0, 9, 17, '2017-09-01'),
#  (934, '1000 Spic SRY Beef', 16, 2, 32.0, 9, 17, '2017-09-01'),
#  (935, '1000 Spic K Prawns', 20, 2, 40.0, 9, 17, '2017-09-01'),
#  (936, 'BYO Per Head', 1.5, 42, 65.5, 9, 17, '2017-09-01'),
#  (937, 'Buchet of Ice', 6, 3, 13.5, 9, 17, '2017-09-01'),
#  (938, 'With spinach', 1, 3, 3.0, 9, 17, '2017-09-01'),
#  (939, 'Curry Puffs', 6.5, 37, 248.0, 10, 17, '2017-10-01'),
#  (940, 'Large Samosas', 6.5, 22, 149.15, 10, 17, '2017-10-01'),
#  (941, 'Samosas - Vege', 7.5, 22, 165.0, 10, 17, '2017-10-01'),
#  (942, 'Mini Spring Rolls', 7.5, 17, 127.5, 10, 17, '2017-10-01'),
#  (943, 'Curry Samosas', 4, 14, 66.0, 10, 17, '2017-10-01'),
#  (944, 'Onion Bhajia', 5.5, 70, 415.0, 10, 17, '2017-10-01'),
#  (945, 'chicken sticks', 9, 22, 184.5, 10, 17, '2017-10-01'),
#  (946, 'chicken strips', 8, 14, 120.0, 10, 17, '2017-10-01'),
#  (947, 'Butter Chicken', 16.5, 236, 3989.5, 10, 17, '2017-10-01'),
#  (948, 'Madras Chicken', 16, 9, 148.0, 10, 17, '2017-10-01'),
#  (949, 'Chicken Korma', 16.5, 33, 561.0, 10, 17, '2017-10-01'),
#  (950, 'CH Tikka Masala', 16, 23, 388.0, 10, 17, '2017-10-01'),
#  (951, 'Chicken Vindaloo', 16, 5, 80.0, 10, 17, '2017-10-01'),
#  (952, 'Mustard Chicken', 16, 28, 466.0, 10, 17, '2017-10-01'),
#  (953, 'Chk In Coconut', 16, 4, 68.0, 10, 17, '2017-10-01'),
#  (954, 'Chicken Jalfrezi', 16, 7, 114.0, 10, 17, '2017-10-01'),
#  (955, 'Chefs SP Chicken.', 16, 14, 234.0, 10, 17, '2017-10-01'),
#  (956, 'Kukulmas Curry', 16, 14, 236.0, 10, 17, '2017-10-01'),
#  (957, 'Rogan Josh', 19, 40, 689.0, 10, 17, '2017-10-01'),
#  (958, 'Palak Gosht', 17.5, 12, 213.0, 10, 17, '2017-10-01'),
#  (959, 'Madras Lamb', 17, 13, 235.0, 10, 17, '2017-10-01'),
#  (960, 'Lamb Korma', 17, 35, 629.0, 10, 17, '2017-10-01'),
#  (961, 'Lamb Vindaloo', 17, 11, 195.0, 10, 17, '2017-10-01'),
#  (962, 'Chefs SP Lamb', 17, 14, 250.0, 10, 17, '2017-10-01'),
#  (963, 'Lamb Masala', 19, 15, 275.0, 10, 17, '2017-10-01'),
#  (964, 'Beef Vindaloo', 16, 27, 440.0, 10, 17, '2017-10-01'),
#  (965, 'Beef Jalfrezi', 16, 6, 100.0, 10, 17, '2017-10-01'),
#  (966, 'Madras Beef', 18, 18, 304.0, 10, 17, '2017-10-01'),
#  (967, 'Moghlai beef', 16, 9, 156.0, 10, 17, '2017-10-01'),
#  (968, 'Beef Korma', 18, 16, 270.0, 10, 17, '2017-10-01'),
#  (969, 'Chefs Sp beef', 16, 14, 236.0, 10, 17, '2017-10-01'),
#  (970, 'Chefs SP Prawn.', 18, 8, 152.0, 10, 17, '2017-10-01'),
#  (971, 'Mixed Seafood', 21, 9, 183.0, 10, 17, '2017-10-01'),
#  (972, 'K Praw N Coconut', 20, 9, 168.0, 10, 17, '2017-10-01'),
#  (973, 'Spicy King Prawn', 18, 5, 98.0, 10, 17, '2017-10-01'),
#  (974, 'Prawn Vindaloo', 20, 1, 20.0, 10, 17, '2017-10-01'),
#  (975, 'Madras Prawn', 18, 6, 112.0, 10, 17, '2017-10-01'),
#  (976, 'Fish in Coconut', 19, 4, 76.0, 10, 17, '2017-10-01'),
#  (977, 'Chefs SP fish', 18, 9, 170.0, 10, 17, '2017-10-01'),
#  (978, 'Vege Korma', 14, 11, 159.0, 10, 17, '2017-10-01'),
#  (979, 'Potato Bhaji', 14, 2, 28.0, 10, 17, '2017-10-01'),
#  (980, 'Aloo Mattar', 14, 4, 58.0, 10, 17, '2017-10-01'),
#  (981, 'Channa Masala', 14, 7, 99.0, 10, 17, '2017-10-01'),
#  (982, 'Devilled Potato', 14, 9, 129.0, 10, 17, '2017-10-01'),
#  (983, 'Paneer Masala', 15, 9, 138.0, 10, 17, '2017-10-01'),
#  (984, 'Palak Paneer', 15.5, 19, 296.0, 10, 17, '2017-10-01'),
#  (985, 'Butter Paneer', 15, 8, 125.0, 10, 17, '2017-10-01'),
#  (986, 'Cabbage/Potato', 14, 13, 186.0, 10, 17, '2017-10-01'),
#  (987, 'Devilled Cabbage', 14, 4, 57.0, 10, 17, '2017-10-01'),
#  (988, 'Pumpkin', 15, 12, 181.0, 10, 17, '2017-10-01'),
#  (989, 'Dhal', 14, 15, 216.0, 10, 17, '2017-10-01'),
#  (990, 'Parippu', 14, 7, 100.0, 10, 17, '2017-10-01'),
#  (991, 'Dhal Makhani', 15, 8, 120.0, 10, 17, '2017-10-01'),
#  (992, 'Green Bean Garlic', 14, 9, 131.0, 10, 17, '2017-10-01'),
#  (993, 'Potato Masala', 15, 7, 100.0, 10, 17, '2017-10-01'),
#  (994, 'Potato Curry', 14, 8, 112.0, 10, 17, '2017-10-01'),
#  (995, 'Vege Butter Chick', 15, 11, 166.0, 10, 17, '2017-10-01'),
#  (996, 'Veg Chick Vinloo', 15, 2, 30.0, 10, 17, '2017-10-01'),
#  (997, 'Vege St Fry Chick', 15, 3, 45.0, 10, 17, '2017-10-01'),
#  (998, 'Pepper Beef', 18, 1, 18.0, 10, 17, '2017-10-01'),
#  (999, 'Pepper K Prawn', 20, 1, 20.0, 10, 17, '2017-10-01'),
#  (1000, 'Yellow Rice Medium', 3.5, 45, 181.5, 10, 17, '2017-10-01'),
#  ...]

# %%
rows = session.query(sales).count()
rows
# Out:
# 8625

# %% [markdown]
# Close Connection

# %%
conn.close()

# %%
session.close()

# %% [markdown]
# Transform and load - Meat Historical Data

# %%
meat_master_df = pd.DataFrame()

# %% [markdown]
# Function to clean Meat Historical Data dataframe

# %%
def Import_clean_meat_df(df,item,meat_master_df):
    df = df.drop(labels=0)
    if item =='beef':
        df = df.rename(columns={'Beef - Monthly Price (Australian Dollar per Kilogram)': 'date', 'Unnamed: 1':'price', 'Unnamed: 2': 'percentage change'})
        print('beef')
    elif item == 'chicken':
        df = df.rename(columns={'Poultry (chicken) - Monthly Price (Australian Dollar per Kilogram)': 'date', 'Unnamed: 1':'price', 'Unnamed: 2': 'percentage change'})
        print('chicken')

    df['date'] = pd.to_datetime(df['date'], format="%b-%y")
    df['date'] = df['date'].dt.strftime("%b-%y")
    
    df['type'] = item

    df['percentage change'] = df['percentage change'].str.strip("%")
    df['percentage change'] = df['percentage change'].str.strip()
    
    df = df.drop(labels=1)
    
    df['percentage change'] = df['percentage change'].astype(float)
   
    df['price'] = df['price'].astype(float)
    
    meat_master_df = meat_master_df.append(df,ignore_index=True)
    
    return (meat_master_df)

# %% [markdown]
# Store file names

# %%
filename = ['beef', 'chicken']

# %% [markdown]
# Load filenames and import to dataframe using funtion to format dataframe and storing to meat_master_df

# %%
for files in filename:
    file = 'Resources/MeatPriceData/' + files + '.csv'
    df = pd.read_csv(file)
    meat_master_df = Import_clean_meat_df(df,files,meat_master_df)
# Out:
# beef
# chicken

# %%
meat_master_df.head()
# Out:
#      date  price  percentage change  type
# 0  Dec-02   3.57               4.84  beef
# 1  Jan-03   3.50              -1.79  beef
# 2  Feb-03   3.35              -4.42  beef
# 3  Mar-03   3.35               0.14  beef
# 4  Apr-03   3.24              -3.55  beef

# %%
meat_master_df.tail()
# Out:
#        date  price  percentage change     type
# 471  May-22   5.25               5.83  chicken
# 472  Jun-22   5.22              -0.62  chicken
# 473  Jul-22   5.16              -1.16  chicken
# 474  Aug-22   4.77              -7.53  chicken
# 475  Sep-22   4.96               3.87  chicken

# %%
meat_master_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 476 entries, 0 to 475
# Data columns (total 4 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   date               476 non-null    object
#  1   price              476 non-null    float64
#  2   percentage change  476 non-null    float64
#  3   type               476 non-null    object
# dtypes: float64(2), object(2)
# memory usage: 15.0+ KB

# %% [markdown]
# Create and Load SQlite database with Meat Historical data

# %%
Base = declarative_base()

# %% [markdown]
# Create meat_history table

# %%
class meat_history(Base):
    __tablename__ = "meat_historical_prices"
    id = Column(Integer, primary_key=True)
    date = Column(String(255))
    price = Column(Float)
    percentage_change = Column(Float)
    type = Column(String(255))

# %% [markdown]
# connect to sqlite database

# %%
engine = create_engine("sqlite:///RestaurantDB.sqlite")

# %%
conn = engine.connect()
Base.metadata.create_all(engine)
session = Session(bind=engine)

# %% [markdown]
# Load and commit each row of the meat_master_df into an sql table row

# %%
for row in range(len(meat_master_df)):
    
    sqldata = meat_history(date = meat_master_df.loc[row,'date'],price = meat_master_df.loc[row,'price'], percentage_change = meat_master_df.loc[row,'percentage change'],
    type=meat_master_df.loc[row,'type'])
    session.add(sqldata)

# %%
session.commit()

# %% [markdown]
# Inspect table for data

# %%
inspector = inspect(engine)

# %%
inspector.get_table_names()
# Out:
# ['meat_historical_prices', 'sales']

# %%
engine.execute('SELECT * FROM meat_historical_prices').fetchall()
# Out:
# [(1, 'Dec-02', 3.57, 4.84, 'beef'),
#  (2, 'Jan-03', 3.5, -1.79, 'beef'),
#  (3, 'Feb-03', 3.35, -4.42, 'beef'),
#  (4, 'Mar-03', 3.35, 0.14, 'beef'),
#  (5, 'Apr-03', 3.24, -3.55, 'beef'),
#  (6, 'May-03', 2.91, -10.16, 'beef'),
#  (7, 'Jun-03', 2.82, -3.13, 'beef'),
#  (8, 'Jul-03', 2.89, 2.49, 'beef'),
#  (9, 'Aug-03', 3.24, 12.31, 'beef'),
#  (10, 'Sep-03', 3.43, 5.95, 'beef'),
#  (11, 'Oct-03', 3.36, -2.22, 'beef'),
#  (12, 'Nov-03', 3.62, 7.77, 'beef'),
#  (13, 'Dec-03', 3.45, -4.54, 'beef'),
#  (14, 'Jan-04', 3.3, -4.42, 'beef'),
#  (15, 'Feb-04', 3.07, -6.89, 'beef'),
#  (16, 'Mar-04', 3.12, 1.55, 'beef'),
#  (17, 'Apr-04', 3.27, 4.65, 'beef'),
#  (18, 'May-04', 3.8, 16.42, 'beef'),
#  (19, 'Jun-04', 3.98, 4.56, 'beef'),
#  (20, 'Jul-04', 3.92, -1.34, 'beef'),
#  (21, 'Aug-04', 4.11, 4.78, 'beef'),
#  (22, 'Sep-04', 4.18, 1.65, 'beef'),
#  (23, 'Oct-04', 3.81, -8.91, 'beef'),
#  (24, 'Nov-04', 3.6, -5.46, 'beef'),
#  (25, 'Dec-04', 3.53, -1.77, 'beef'),
#  (26, 'Jan-05', 3.52, -0.47, 'beef'),
#  (27, 'Feb-05', 3.46, -1.68, 'beef'),
#  (28, 'Mar-05', 3.5, 1.19, 'beef'),
#  (29, 'Apr-05', 3.55, 1.36, 'beef'),
#  (30, 'May-05', 3.62, 1.93, 'beef'),
#  (31, 'Jun-05', 3.63, 0.29, 'beef'),
#  (32, 'Jul-05', 3.74, 3.02, 'beef'),
#  (33, 'Aug-05', 3.63, -2.95, 'beef'),
#  (34, 'Sep-05', 3.59, -0.87, 'beef'),
#  (35, 'Oct-05', 3.58, -0.28, 'beef'),
#  (36, 'Nov-05', 3.67, 2.52, 'beef'),
#  (37, 'Dec-05', 3.57, -2.89, 'beef'),
#  (38, 'Jan-06', 3.5, -2.04, 'beef'),
#  (39, 'Feb-06', 3.58, 2.36, 'beef'),
#  (40, 'Mar-06', 3.6, 0.67, 'beef'),
#  (41, 'Apr-06', 3.54, -1.75, 'beef'),
#  (42, 'May-06', 3.43, -2.94, 'beef'),
#  (43, 'Jun-06', 3.47, 1.1, 'beef'),
#  (44, 'Jul-06', 3.49, 0.5, 'beef'),
#  (45, 'Aug-06', 3.49, -0.1, 'beef'),
#  (46, 'Sep-06', 3.54, 1.62, 'beef'),
#  (47, 'Oct-06', 3.57, 0.75, 'beef'),
#  (48, 'Nov-06', 3.59, 0.58, 'beef'),
#  (49, 'Dec-06', 3.43, -4.31, 'beef'),
#  (50, 'Jan-07', 3.43, -0.08, 'beef'),
#  (51, 'Feb-07', 3.46, 0.95, 'beef'),
#  (52, 'Mar-07', 3.4, -1.93, 'beef'),
#  (53, 'Apr-07', 3.26, -4.06, 'beef'),
#  (54, 'May-07', 3.27, 0.35, 'beef'),
#  (55, 'Jun-07', 3.18, -2.68, 'beef'),
#  (56, 'Jul-07', 3.08, -3.3, 'beef'),
#  (57, 'Aug-07', 3.25, 5.6, 'beef'),
#  (58, 'Sep-07', 3.18, -2.17, 'beef'),
#  (59, 'Oct-07', 2.97, -6.62, 'beef'),
#  (60, 'Nov-07', 3.03, 1.97, 'beef'),
#  (61, 'Dec-07', 3.13, 3.3, 'beef'),
#  (62, 'Jan-08', 3.14, 0.46, 'beef'),
#  (63, 'Feb-08', 3.17, 0.71, 'beef'),
#  (64, 'Mar-08', 3.25, 2.71, 'beef'),
#  (65, 'Apr-08', 3.4, 4.45, 'beef'),
#  (66, 'May-08', 3.7, 8.93, 'beef'),
#  (67, 'Jun-08', 3.85, 4.08, 'beef'),
#  (68, 'Jul-08', 4.08, 6.08, 'beef'),
#  (69, 'Aug-08', 4.36, 6.81, 'beef'),
#  (70, 'Sep-08', 4.34, -0.47, 'beef'),
#  (71, 'Oct-08', 4.55, 4.83, 'beef'),
#  (72, 'Nov-08', 4.17, -8.43, 'beef'),
#  (73, 'Dec-08', 3.98, -4.4, 'beef'),
#  (74, 'Jan-09', 3.9, -2.2, 'beef'),
#  (75, 'Feb-09', 3.91, 0.47, 'beef'),
#  (76, 'Mar-09', 3.93, 0.47, 'beef'),
#  (77, 'Apr-09', 3.71, -5.72, 'beef'),
#  (78, 'May-09', 3.57, -3.74, 'beef'),
#  (79, 'Jun-09', 3.42, -4.28, 'beef'),
#  (80, 'Jul-09', 3.47, 1.63, 'beef'),
#  (81, 'Aug-09', 3.36, -3.34, 'beef'),
#  (82, 'Sep-09', 3.26, -2.74, 'beef'),
#  (83, 'Oct-09', 3.03, -7.28, 'beef'),
#  (84, 'Nov-09', 3.08, 1.63, 'beef'),
#  (85, 'Dec-09', 3.19, 3.75, 'beef'),
#  (86, 'Jan-10', 3.3, 3.46, 'beef'),
#  (87, 'Feb-10', 3.62, 9.71, 'beef'),
#  (88, 'Mar-10', 3.73, 2.92, 'beef'),
#  (89, 'Apr-10', 3.95, 5.96, 'beef'),
#  (90, 'May-10', 4.11, 3.99, 'beef'),
#  (91, 'Jun-10', 3.91, -4.91, 'beef'),
#  (92, 'Jul-10', 3.74, -4.24, 'beef'),
#  (93, 'Aug-10', 3.79, 1.3, 'beef'),
#  (94, 'Sep-10', 3.62, -4.44, 'beef'),
#  (95, 'Oct-10', 3.44, -5.11, 'beef'),
#  (96, 'Nov-10', 3.52, 2.59, 'beef'),
#  (97, 'Dec-10', 3.92, 11.33, 'beef'),
#  (98, 'Jan-11', 4.21, 7.38, 'beef'),
#  (99, 'Feb-11', 4.05, -3.98, 'beef'),
#  (100, 'Mar-11', 4.15, 2.53, 'beef'),
#  (101, 'Apr-11', 4.1, -1.07, 'beef'),
#  (102, 'May-11', 3.89, -5.15, 'beef'),
#  (103, 'Jun-11', 3.72, -4.53, 'beef'),
#  (104, 'Jul-11', 3.66, -1.52, 'beef'),
#  (105, 'Aug-11', 3.75, 2.45, 'beef'),
#  (106, 'Sep-11', 3.75, 0.04, 'beef'),
#  (107, 'Oct-11', 3.87, 3.07, 'beef'),
#  (108, 'Nov-11', 4.14, 7.17, 'beef'),
#  (109, 'Dec-11', 4.17, 0.69, 'beef'),
#  (110, 'Jan-12', 4.1, -1.74, 'beef'),
#  (111, 'Feb-12', 4.02, -1.94, 'beef'),
#  (112, 'Mar-12', 4.13, 2.66, 'beef'),
#  (113, 'Apr-12', 4.14, 0.45, 'beef'),
#  (114, 'May-12', 4.22, 1.73, 'beef'),
#  (115, 'Jun-12', 4.13, -2.14, 'beef'),
#  (116, 'Jul-12', 3.92, -5.11, 'beef'),
#  (117, 'Aug-12', 3.92, 0.02, 'beef'),
#  (118, 'Sep-12', 3.9, -0.33, 'beef'),
#  (119, 'Oct-12', 3.95, 1.3, 'beef'),
#  (120, 'Nov-12', 4.12, 4.21, 'beef'),
#  (121, 'Dec-12', 4.17, 1.17, 'beef'),
#  (122, 'Jan-13', 4.15, -0.42, 'beef'),
#  (123, 'Feb-13', 4.21, 1.5, 'beef'),
#  (124, 'Mar-13', 4.15, -1.49, 'beef'),
#  (125, 'Apr-13', 4.11, -0.96, 'beef'),
#  (126, 'May-13', 4.13, 0.47, 'beef'),
#  (127, 'Jun-13', 4.17, 0.9, 'beef'),
#  (128, 'Jul-13', 4.29, 3.03, 'beef'),
#  (129, 'Aug-13', 4.37, 1.73, 'beef'),
#  (130, 'Sep-13', 4.29, -1.69, 'beef'),
#  (131, 'Oct-13', 4.24, -1.16, 'beef'),
#  (132, 'Nov-13', 4.43, 4.28, 'beef'),
#  (133, 'Dec-13', 4.65, 5.11, 'beef'),
#  (134, 'Jan-14', 4.71, 1.27, 'beef'),
#  (135, 'Feb-14', 4.78, 1.35, 'beef'),
#  (136, 'Mar-14', 4.93, 3.18, 'beef'),
#  (137, 'Apr-14', 4.67, -5.21, 'beef'),
#  (138, 'May-14', 4.7, 0.7, 'beef'),
#  (139, 'Jun-14', 4.85, 3.07, 'beef'),
#  (140, 'Jul-14', 5.5, 13.54, 'beef'),
#  (141, 'Aug-14', 6.22, 13.07, 'beef'),
#  (142, 'Sep-14', 6.81, 9.41, 'beef'),
#  (143, 'Oct-14', 6.77, -0.54, 'beef'),
#  (144, 'Nov-14', 6.74, -0.44, 'beef'),
#  (145, 'Dec-14', 6.61, -1.89, 'beef'),
#  (146, 'Jan-15', 6.56, -0.85, 'beef'),
#  (147, 'Feb-15', 6.27, -4.47, 'beef'),
#  (148, 'Mar-15', 6.11, -2.54, 'beef'),
#  (149, 'Apr-15', 6.22, 1.94, 'beef'),
#  (150, 'May-15', 5.69, -8.54, 'beef'),
#  (151, 'Jun-15', 5.75, 0.99, 'beef'),
#  (152, 'Jul-15', 6.27, 9.09, 'beef'),
#  (153, 'Aug-15', 6.54, 4.29, 'beef'),
#  (154, 'Sep-15', 6.49, -0.8, 'beef'),
#  (155, 'Oct-15', 5.89, -9.27, 'beef'),
#  (156, 'Nov-15', 5.64, -4.2, 'beef'),
#  (157, 'Dec-15', 5.24, -7.03, 'beef'),
#  (158, 'Jan-16', 5.17, -1.36, 'beef'),
#  (159, 'Feb-16', 5.42, 4.74, 'beef'),
#  (160, 'Mar-16', 5.39, -0.43, 'beef'),
#  (161, 'Apr-16', 5.17, -4.16, 'beef'),
#  (162, 'May-16', 5.51, 6.66, 'beef'),
#  (163, 'Jun-16', 5.56, 0.83, 'beef'),
#  (164, 'Jul-16', 5.66, 1.82, 'beef'),
#  (165, 'Aug-16', 5.55, -1.88, 'beef'),
#  (166, 'Sep-16', 5.43, -2.28, 'beef'),
#  (167, 'Oct-16', 5.3, -2.27, 'beef'),
#  (168, 'Nov-16', 5.7, 7.42, 'beef'),
#  (169, 'Dec-16', 5.63, -1.27, 'beef'),
#  (170, 'Jan-17', 5.48, -2.6, 'beef'),
#  (171, 'Feb-17', 5.52, 0.72, 'beef'),
#  (172, 'Mar-17', 5.7, 3.35, 'beef'),
#  (173, 'Apr-17', 5.85, 2.66, 'beef'),
#  (174, 'May-17', 6.19, 5.71, 'beef'),
#  (175, 'Jun-17', 6.2, 0.14, 'beef'),
#  (176, 'Jul-17', 5.99, -3.34, 'beef'),
#  (177, 'Aug-17', 5.65, -5.73, 'beef'),
#  (178, 'Sep-17', 5.39, -4.48, 'beef'),
#  (179, 'Oct-17', 5.45, 1.08, 'beef'),
#  (180, 'Nov-17', 5.68, 4.16, 'beef'),
#  (181, 'Dec-17', 5.6, -1.31, 'beef'),
#  (182, 'Jan-18', 5.42, -3.31, 'beef'),
#  (183, 'Feb-18', 5.52, 1.91, 'beef'),
#  (184, 'Mar-18', 5.72, 3.49, 'beef'),
#  (185, 'Apr-18', 5.69, -0.43, 'beef'),
#  (186, 'May-18', 5.74, 0.89, 'beef'),
#  (187, 'Jun-18', 5.66, -1.43, 'beef'),
#  (188, 'Jul-18', 5.66, -0.02, 'beef'),
#  (189, 'Aug-18', 5.61, -0.83, 'beef'),
#  (190, 'Sep-18', 5.57, -0.77, 'beef'),
#  (191, 'Oct-18', 5.43, -2.41, 'beef'),
#  (192, 'Nov-18', 5.45, 0.34, 'beef'),
#  (193, 'Dec-18', 5.82, 6.75, 'beef'),
#  (194, 'Jan-19', 5.94, 2.01, 'beef'),
#  (195, 'Feb-19', 5.99, 0.93, 'beef'),
#  (196, 'Mar-19', 6.33, 5.6, 'beef'),
#  (197, 'Apr-19', 6.61, 4.41, 'beef'),
#  (198, 'May-19', 6.62, 0.21, 'beef'),
#  (199, 'Jun-19', 6.67, 0.76, 'beef'),
#  (200, 'Jul-19', 6.63, -0.65, 'beef'),
#  (201, 'Aug-19', 6.79, 2.52, 'beef'),
#  (202, 'Sep-19', 6.83, 0.49, 'beef'),
#  (203, 'Oct-19', 7.16, 4.86, 'beef'),
#  (204, 'Nov-19', 8.69, 21.4, 'beef'),
#  (205, 'Dec-19', 8.12, -6.61, 'beef'),
#  (206, 'Jan-20', 7.34, -9.59, 'beef'),
#  (207, 'Feb-20', 7.08, -3.56, 'beef'),
#  (208, 'Mar-20', 7.21, 1.9, 'beef'),
#  (209, 'Apr-20', 7.07, -1.95, 'beef'),
#  (210, 'May-20', 7.81, 10.41, 'beef'),
#  (211, 'Jun-20', 7.39, -5.3, 'beef'),
#  (212, 'Jul-20', 6.68, -9.62, 'beef'),
#  (213, 'Aug-20', 6.43, -3.74, 'beef'),
#  (214, 'Sep-20', 6.36, -1.11, 'beef'),
#  (215, 'Oct-20', 6.21, -2.42, 'beef'),
#  (216, 'Nov-20', 6.07, -2.24, 'beef'),
#  (217, 'Dec-20', 5.87, -3.21, 'beef'),
#  (218, 'Jan-21', 5.77, -1.72, 'beef'),
#  (219, 'Feb-21', 6.01, 4.16, 'beef'),
#  (220, 'Mar-21', 6.12, 1.83, 'beef'),
#  (221, 'Apr-21', 6.72, 9.7, 'beef'),
#  (222, 'May-21', 7.06, 5.13, 'beef'),
#  (223, 'Jun-21', 7.43, 5.26, 'beef'),
#  (224, 'Jul-21', 7.54, 1.42, 'beef'),
#  (225, 'Aug-21', 7.69, 2.01, 'beef'),
#  (226, 'Sep-21', 7.75, 0.79, 'beef'),
#  (227, 'Oct-21', 7.7, -0.66, 'beef'),
#  (228, 'Nov-21', 8.12, 5.53, 'beef'),
#  (229, 'Dec-21', 8.35, 2.8, 'beef'),
#  (230, 'Jan-22', 8.32, -0.38, 'beef'),
#  (231, 'Feb-22', 8.68, 4.35, 'beef'),
#  (232, 'Mar-22', 8.48, -2.33, 'beef'),
#  (233, 'Apr-22', 8.29, -2.22, 'beef'),
#  (234, 'May-22', 8.63, 4.12, 'beef'),
#  (235, 'Jun-22', 8.5, -1.46, 'beef'),
#  (236, 'Jul-22', 8.51, 0.07, 'beef'),
#  (237, 'Aug-22', 8.2, -3.6, 'beef'),
#  (238, 'Sep-22', 8.46, 3.09, 'beef'),
#  (239, 'Dec-02', 2.41, -0.38, 'chicken'),
#  (240, 'Jan-03', 2.35, -2.52, 'chicken'),
#  (241, 'Feb-03', 2.34, -0.59, 'chicken'),
#  (242, 'Mar-03', 2.34, 0.07, 'chicken'),
#  (243, 'Apr-03', 2.3, -1.81, 'chicken'),
#  (244, 'May-03', 2.2, -4.52, 'chicken'),
#  (245, 'Jun-03', 2.18, -0.56, 'chicken'),
#  (246, 'Jul-03', 2.25, 3.11, 'chicken'),
#  (247, 'Aug-03', 2.32, 3.03, 'chicken'),
#  (248, 'Sep-03', 2.31, -0.21, 'chicken'),
#  (249, 'Oct-03', 2.18, -5.98, 'chicken'),
#  (250, 'Nov-03', 2.11, -3.05, 'chicken'),
#  (251, 'Dec-03', 2.06, -2.4, 'chicken'),
#  (252, 'Jan-04', 1.99, -3.41, 'chicken'),
#  (253, 'Feb-04', 2.03, 2.19, 'chicken'),
#  (254, 'Mar-04', 2.15, 5.69, 'chicken'),
#  (255, 'Apr-04', 2.22, 3.27, 'chicken'),
#  (256, 'May-04', 2.4, 8.12, 'chicken'),
#  (257, 'Jun-04', 2.54, 5.74, 'chicken'),
#  (258, 'Jul-04', 2.49, -1.99, 'chicken'),
#  (259, 'Aug-04', 2.49, 0.26, 'chicken'),
#  (260, 'Sep-04', 2.45, -1.56, 'chicken'),
#  (261, 'Oct-04', 2.29, -6.56, 'chicken'),
#  (262, 'Nov-04', 2.14, -6.48, 'chicken'),
#  (263, 'Dec-04', 2.11, -1.42, 'chicken'),
#  (264, 'Jan-05', 2.12, 0.27, 'chicken'),
#  (265, 'Feb-05', 2.09, -1.44, 'chicken'),
#  (266, 'Mar-05', 2.07, -0.65, 'chicken'),
#  (267, 'Apr-05', 2.11, 1.73, 'chicken'),
#  (268, 'May-05', 2.14, 1.44, 'chicken'),
#  (269, 'Jun-05', 2.14, -0.07, 'chicken'),
#  (270, 'Jul-05', 2.19, 2.54, 'chicken'),
#  (271, 'Aug-05', 2.17, -1.19, 'chicken'),
#  (272, 'Sep-05', 2.17, 0.09, 'chicken'),
#  (273, 'Oct-05', 2.18, 0.34, 'chicken'),
#  (274, 'Nov-05', 2.18, 0.02, 'chicken'),
#  (275, 'Dec-05', 2.11, -2.91, 'chicken'),
#  (276, 'Jan-06', 2.05, -2.81, 'chicken'),
#  (277, 'Feb-06', 2.07, 0.54, 'chicken'),
#  (278, 'Mar-06', 2.08, 0.49, 'chicken'),
#  (279, 'Apr-06', 2.03, -2.31, 'chicken'),
#  (280, 'May-06', 1.97, -3.03, 'chicken'),
#  (281, 'Jun-06', 2.05, 4.44, 'chicken'),
#  (282, 'Jul-06', 2.05, -0.12, 'chicken'),
#  (283, 'Aug-06', 2.03, -0.96, 'chicken'),
#  (284, 'Sep-06', 2.06, 1.51, 'chicken'),
#  (285, 'Oct-06', 2.04, -0.92, 'chicken'),
#  (286, 'Nov-06', 1.97, -3.6, 'chicken'),
#  (287, 'Dec-06', 1.95, -1.18, 'chicken'),
#  (288, 'Jan-07', 2.0, 2.91, 'chicken'),
#  (289, 'Feb-07', 2.08, 4.04, 'chicken'),
#  (290, 'Mar-07', 2.12, 1.83, 'chicken'),
#  (291, 'Apr-07', 2.08, -1.78, 'chicken'),
#  (292, 'May-07', 2.12, 1.72, 'chicken'),
#  (293, 'Jun-07', 2.11, -0.28, 'chicken'),
#  (294, 'Jul-07', 2.06, -2.39, 'chicken'),
#  (295, 'Aug-07', 2.16, 4.81, 'chicken'),
#  (296, 'Sep-07', 2.13, -1.62, 'chicken'),
#  (297, 'Oct-07', 1.96, -8.01, 'chicken'),
#  (298, 'Nov-07', 1.9, -2.75, 'chicken'),
#  (299, 'Dec-07', 1.94, 1.72, 'chicken'),
#  (300, 'Jan-08', 1.93, -0.4, 'chicken'),
#  (301, 'Feb-08', 1.91, -1.2, 'chicken'),
#  (302, 'Mar-08', 1.93, 1.45, 'chicken'),
#  (303, 'Apr-08', 1.94, 0.6, 'chicken'),
#  (304, 'May-08', 1.94, -0.31, 'chicken'),
#  (305, 'Jun-08', 1.99, 2.53, 'chicken'),
#  (306, 'Jul-08', 2.03, 1.93, 'chicken'),
#  (307, 'Aug-08', 2.21, 9.31, 'chicken'),
#  (308, 'Sep-08', 2.38, 7.36, 'chicken'),
#  (309, 'Oct-08', 2.82, 18.77, 'chicken'),
#  (310, 'Nov-08', 2.93, 3.78, 'chicken'),
#  (311, 'Dec-08', 2.88, -1.88, 'chicken'),
#  (312, 'Jan-09', 2.83, -1.46, 'chicken'),
#  (313, 'Feb-09', 2.94, 3.88, 'chicken'),
#  (314, 'Mar-09', 2.85, -3.25, 'chicken'),
#  (315, 'Apr-09', 2.64, -7.29, 'chicken'),
#  (316, 'May-09', 2.52, -4.59, 'chicken'),
#  (317, 'Jun-09', 2.42, -3.99, 'chicken'),
#  (318, 'Jul-09', 2.43, 0.33, 'chicken'),
#  (319, 'Aug-09', 2.29, -5.66, 'chicken'),
#  (320, 'Sep-09', 2.17, -5.11, 'chicken'),
#  (321, 'Oct-09', 2.01, -7.28, 'chicken'),
#  (322, 'Nov-09', 1.97, -2.32, 'chicken'),
#  (323, 'Dec-09', 2.01, 1.95, 'chicken'),
#  (324, 'Jan-10', 2.0, -0.24, 'chicken'),
#  (325, 'Feb-10', 2.08, 3.78, 'chicken'),
#  (326, 'Mar-10', 2.03, -2.3, 'chicken'),
#  (327, 'Apr-10', 2.03, 0.03, 'chicken'),
#  (328, 'May-10', 2.19, 8.01, 'chicken'),
#  (329, 'Jun-10', 2.25, 2.76, 'chicken'),
#  (330, 'Jul-10', 2.22, -1.47, 'chicken'),
#  (331, 'Aug-10', 2.16, -2.86, 'chicken'),
#  (332, 'Sep-10', 2.06, -4.38, 'chicken'),
#  (333, 'Oct-10', 1.95, -5.53, 'chicken'),
#  (334, 'Nov-10', 1.89, -2.77, 'chicken'),
#  (335, 'Dec-10', 1.9, 0.43, 'chicken'),
#  (336, 'Jan-11', 1.88, -1.1, 'chicken'),
#  (337, 'Feb-11', 1.86, -0.86, 'chicken'),
#  (338, 'Mar-11', 1.88, 0.9, 'chicken'),
#  (339, 'Apr-11', 1.8, -4.27, 'chicken'),
#  (340, 'May-11', 1.79, -0.75, 'chicken'),
#  (341, 'Jun-11', 1.81, 1.33, 'chicken'),
#  (342, 'Jul-11', 1.79, -1.01, 'chicken'),
#  (343, 'Aug-11', 1.85, 3.24, 'chicken'),
#  (344, 'Sep-11', 1.92, 3.71, 'chicken'),
#  (345, 'Oct-11', 1.93, 0.71, 'chicken'),
#  (346, 'Nov-11', 1.94, 0.53, 'chicken'),
#  (347, 'Dec-11', 1.96, 0.72, 'chicken'),
#  (348, 'Jan-12', 1.91, -2.17, 'chicken'),
#  (349, 'Feb-12', 1.87, -2.11, 'chicken'),
#  (350, 'Mar-12', 1.94, 3.74, 'chicken'),
#  (351, 'Apr-12', 1.99, 2.35, 'chicken'),
#  (352, 'May-12', 2.07, 3.92, 'chicken'),
#  (353, 'Jun-12', 2.08, 0.72, 'chicken'),
#  (354, 'Jul-12', 2.03, -2.52, 'chicken'),
#  (355, 'Aug-12', 2.0, -1.68, 'chicken'),
#  (356, 'Sep-12', 2.03, 1.61, 'chicken'),
#  (357, 'Oct-12', 2.05, 1.05, 'chicken'),
#  (358, 'Nov-12', 2.05, -0.2, 'chicken'),
#  (359, 'Dec-12', 2.05, 0.25, 'chicken'),
#  (360, 'Jan-13', 2.11, 3.06, 'chicken'),
#  (361, 'Feb-13', 2.12, 0.36, 'chicken'),
#  (362, 'Mar-13', 2.24, 5.36, 'chicken'),
#  (363, 'Apr-13', 2.2, -1.36, 'chicken'),
#  (364, 'May-13', 2.4, 8.75, 'chicken'),
#  (365, 'Jun-13', 2.55, 6.15, 'chicken'),
#  (366, 'Jul-13', 2.42, -4.94, 'chicken'),
#  (367, 'Aug-13', 2.26, -6.75, 'chicken'),
#  (368, 'Sep-13', 2.13, -5.54, 'chicken'),
#  (369, 'Oct-13', 2.06, -3.37, 'chicken'),
#  (370, 'Nov-13', 2.17, 5.4, 'chicken'),
#  (371, 'Dec-13', 2.3, 6.16, 'chicken'),
#  (372, 'Jan-14', 2.38, 3.23, 'chicken'),
#  (373, 'Feb-14', 2.25, -5.24, 'chicken'),
#  (374, 'Mar-14', 2.49, 10.53, 'chicken'),
#  (375, 'Apr-14', 2.56, 2.58, 'chicken'),
#  (376, 'May-14', 2.75, 7.58, 'chicken'),
#  (377, 'Jun-14', 2.72, -0.95, 'chicken'),
#  (378, 'Jul-14', 2.61, -4.21, 'chicken'),
#  (379, 'Aug-14', 2.44, -6.46, 'chicken'),
#  (380, 'Sep-14', 2.6, 6.74, 'chicken'),
#  (381, 'Oct-14', 2.69, 3.14, 'chicken'),
#  (382, 'Nov-14', 2.67, -0.71, 'chicken'),
#  (383, 'Dec-14', 2.69, 0.85, 'chicken'),
#  (384, 'Jan-15', 2.75, 2.14, 'chicken'),
#  (385, 'Feb-15', 2.61, -5.13, 'chicken'),
#  (386, 'Mar-15', 2.78, 6.72, 'chicken'),
#  (387, 'Apr-15', 2.98, 7.13, 'chicken'),
#  (388, 'May-15', 2.97, -0.22, 'chicken'),
#  (389, 'Jun-15', 2.95, -0.7, 'chicken'),
#  (390, 'Jul-15', 2.79, -5.43, 'chicken'),
#  (391, 'Aug-15', 2.5, -10.62, 'chicken'),
#  (392, 'Sep-15', 2.39, -4.07, 'chicken'),
#  (393, 'Oct-15', 2.24, -6.64, 'chicken'),
#  (394, 'Nov-15', 2.27, 1.42, 'chicken'),
#  (395, 'Dec-15', 2.4, 5.9, 'chicken'),
#  (396, 'Jan-16', 2.64, 9.79, 'chicken'),
#  (397, 'Feb-16', 2.48, -5.76, 'chicken'),
#  (398, 'Mar-16', 2.48, -0.32, 'chicken'),
#  (399, 'Apr-16', 2.52, 1.75, 'chicken'),
#  (400, 'May-16', 2.81, 11.59, 'chicken'),
#  (401, 'Jun-16', 2.91, 3.44, 'chicken'),
#  (402, 'Jul-16', 2.6, -10.44, 'chicken'),
#  (403, 'Aug-16', 2.28, -12.48, 'chicken'),
#  (404, 'Sep-16', 2.24, -1.75, 'chicken'),
#  (405, 'Oct-16', 2.09, -6.78, 'chicken'),
#  (406, 'Nov-16', 2.33, 11.72, 'chicken'),
#  (407, 'Dec-16', 2.53, 8.37, 'chicken'),
#  (408, 'Jan-17', 2.61, 3.33, 'chicken'),
#  (409, 'Feb-17', 2.53, -3.09, 'chicken'),
#  (410, 'Mar-17', 2.79, 10.34, 'chicken'),
#  (411, 'Apr-17', 2.87, 2.69, 'chicken'),
#  (412, 'May-17', 3.13, 9.32, 'chicken'),
#  (413, 'Jun-17', 3.22, 2.66, 'chicken'),
#  (414, 'Jul-17', 3.01, -6.33, 'chicken'),
#  (415, 'Aug-17', 2.77, -8.22, 'chicken'),
#  (416, 'Sep-17', 2.65, -4.33, 'chicken'),
#  (417, 'Oct-17', 2.54, -4.03, 'chicken'),
#  (418, 'Nov-17', 2.57, 1.2, 'chicken'),
#  (419, 'Dec-17', 2.58, 0.35, 'chicken'),
#  (420, 'Jan-18', 2.61, 1.13, 'chicken'),
#  (421, 'Feb-18', 2.51, -3.64, 'chicken'),
#  (422, 'Mar-18', 2.83, 12.66, 'chicken'),
#  (423, 'Apr-18', 3.07, 8.27, 'chicken'),
#  (424, 'May-18', 3.52, 14.86, 'chicken'),
#  (425, 'Jun-18', 3.63, 3.08, 'chicken'),
#  (426, 'Jul-18', 3.42, -5.9, 'chicken'),
#  (427, 'Aug-18', 3.03, -11.29, 'chicken'),
#  (428, 'Sep-18', 2.82, -7.0, 'chicken'),
#  (429, 'Oct-18', 2.86, 1.38, 'chicken'),
#  (430, 'Nov-18', 2.8, -1.94, 'chicken'),
#  (431, 'Dec-18', 2.9, 3.61, 'chicken'),
#  (432, 'Jan-19', 3.01, 3.7, 'chicken'),
#  (433, 'Feb-19', 2.93, -2.81, 'chicken'),
#  (434, 'Mar-19', 2.92, -0.08, 'chicken'),
#  (435, 'Apr-19', 2.94, 0.48, 'chicken'),
#  (436, 'May-19', 3.01, 2.39, 'chicken'),
#  (437, 'Jun-19', 2.98, -0.85, 'chicken'),
#  (438, 'Jul-19', 2.85, -4.49, 'chicken'),
#  (439, 'Aug-19', 2.81, -1.48, 'chicken'),
#  (440, 'Sep-19', 2.72, -3.2, 'chicken'),
#  (441, 'Oct-19', 2.72, 0.33, 'chicken'),
#  (442, 'Nov-19', 2.71, -0.67, 'chicken'),
#  (443, 'Dec-19', 2.89, 6.78, 'chicken'),
#  (444, 'Jan-20', 3.01, 4.27, 'chicken'),
#  (445, 'Feb-20', 2.82, -6.47, 'chicken'),
#  (446, 'Mar-20', 2.87, 1.88, 'chicken'),
#  (447, 'Apr-20', 2.02, -29.73, 'chicken'),
#  (448, 'May-20', 2.34, 15.76, 'chicken'),
#  (449, 'Jun-20', 2.28, -2.57, 'chicken'),
#  (450, 'Jul-20', 2.16, -5.05, 'chicken'),
#  (451, 'Aug-20', 2.08, -3.57, 'chicken'),
#  (452, 'Sep-20', 2.03, -2.46, 'chicken'),
#  (453, 'Oct-20', 2.11, 3.62, 'chicken'),
#  (454, 'Nov-20', 2.34, 11.3, 'chicken'),
#  (455, 'Dec-20', 2.42, 3.05, 'chicken'),
#  (456, 'Jan-21', 2.34, -3.04, 'chicken'),
#  (457, 'Feb-21', 2.33, -0.31, 'chicken'),
#  (458, 'Mar-21', 2.45, 4.98, 'chicken'),
#  (459, 'Apr-21', 2.94, 19.76, 'chicken'),
#  (460, 'May-21', 3.05, 4.01, 'chicken'),
#  (461, 'Jun-21', 3.11, 1.98, 'chicken'),
#  (462, 'Jul-21', 3.21, 3.05, 'chicken'),
#  (463, 'Aug-21', 3.26, 1.64, 'chicken'),
#  (464, 'Sep-21', 3.26, -0.1, 'chicken'),
#  (465, 'Oct-21', 3.15, -3.43, 'chicken'),
#  (466, 'Nov-21', 3.19, 1.53, 'chicken'),
#  (467, 'Dec-21', 3.85, 20.38, 'chicken'),
#  (468, 'Jan-22', 4.01, 4.36, 'chicken'),
#  (469, 'Feb-22', 3.96, -1.42, 'chicken'),
#  (470, 'Mar-22', 4.53, 14.53, 'chicken'),
#  (471, 'Apr-22', 4.96, 9.55, 'chicken'),
#  (472, 'May-22', 5.25, 5.83, 'chicken'),
#  (473, 'Jun-22', 5.22, -0.62, 'chicken'),
#  (474, 'Jul-22', 5.16, -1.16, 'chicken'),
#  (475, 'Aug-22', 4.77, -7.53, 'chicken'),
#  (476, 'Sep-22', 4.96, 3.87, 'chicken')]

# %%
rows = session.query(meat_history).count()
rows
# Out:
# 476

# %%
conn.close()

session.close()
